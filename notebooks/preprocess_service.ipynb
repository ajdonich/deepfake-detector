# %% [markdown]
# # Deepfake Data Preprocessor
#
# This Notebook is for preprocessing the training data, i.e. (currently anyway) creating difference-blend-mode image files
# for every frame of the faked video, plus a final "fakerprint" image (see comments below). You should be able to preprocess
# kaggle's little sample dataset in only like 20 minutes. This video player: https://darbyjohnston.github.io/DJV/ can play
# the JPG difference-image sequences as if they were a video if you want (Premiere can do this too, but not Quicktime).
#
# Make sure to correctly set the **DATA_LAKE** below before preprocessing (and **run_sample_data** flag if apropos).
#
# #### Main Function Table of Contents:
# + **summarize_data()** - Just has a tertiary look at the dataset and prints out some metrics.
# + **create_fakerframes_cv2()** - Creates the actual difference and fakerprint image files.
# + **preprocess_data()** - Orchestrates calls to faked_video_pairs() and create_fakerframes_cv2() on the dataset.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os, re, time
import functools
import cv2, json
import numpy as np

# For managing relative imports from notebook
if '..' not in sys.path: sys.path.append('..')

import config.config as dfc
import deepfake.dfutillib as df
import deepfake.preprocessor as dproc

# %%
# dproc.Preprocessor().reprocess_block(428, doinsert=False)

# %%
dproc.Preprocessor(minqueued=7).run()
# Out:
# Preprocessing epoch block 379:
#   Total process time: 0.00 min
# Preprocessing epoch block 545:
#   Processed 10 videos, running average time/pair: 5.24 sec
#   Processed 20 videos, running average time/pair: 5.12 sec
#   Processed 30 videos, running average time/pair: 4.49 sec
#   Processed 40 videos, running average time/pair: 5.11 sec
#   Processed 50 videos, running average time/pair: 5.04 sec
#   Processed 60 videos, running average time/pair: 5.44 sec
#   Processed 70 videos, running average time/pair: 6.00 sec
#   Processed 80 videos, running average time/pair: 5.51 sec
#   Processed 90 videos, running average time/pair: 5.04 sec
#   Processed 100 videos, running average time/pair: 5.13 sec
#   Processed 110 videos, running average time/pair: 4.93 sec
#   Processed 120 videos, running average time/pair: 4.86 sec
#   Processed 130 videos, running average time/pair: 4.75 sec
#   Processed 140 videos, running average time/pair: 5.38 sec
#   Processed 150 videos, running average time/pair: 5.56 sec
#   Processed 160 videos, running average time/pair: 5.57 sec
#   Total process time: 14.62 min
# Preprocessing epoch block 220:
#   Processed 10 videos, running average time/pair: 5.33 sec
#   Processed 20 videos, running average time/pair: 5.19 sec
#   Processed 30 videos, running average time/pair: 4.82 sec
#   Processed 40 videos, running average time/pair: 5.09 sec
#   Processed 50 videos, running average time/pair: 5.84 sec
#   Processed 60 videos, running average time/pair: 5.74 sec
#   Processed 70 videos, running average time/pair: 5.26 sec
#   Processed 80 videos, running average time/pair: 4.53 sec
#   Processed 90 videos, running average time/pair: 5.21 sec
#   Processed 100 videos, running average time/pair: 5.30 sec
#   Processed 110 videos, running average time/pair: 4.69 sec
#   Processed 120 videos, running average time/pair: 5.07 sec
#   Processed 130 videos, running average time/pair: 6.16 sec
#   Processed 140 videos, running average time/pair: 5.53 sec
#   Processed 150 videos, running average time/pair: 5.11 sec
#   Processed 160 videos, running average time/pair: 5.01 sec
#   Total process time: 14.46 min
# Preprocessing epoch block 106:
#   Processed 10 videos, running average time/pair: 4.92 sec
#   Processed 20 videos, running average time/pair: 5.16 sec
#   Processed 30 videos, running average time/pair: 4.93 sec
#   Processed 40 videos, running average time/pair: 5.36 sec
#   Processed 50 videos, running average time/pair: 5.45 sec
#   Processed 60 videos, running average time/pair: 5.48 sec
#   Processed 70 videos, running average time/pair: 4.94 sec
#   Processed 80 videos, running average time/pair: 5.70 sec
#   Processed 90 videos, running average time/pair: 4.76 sec
#   Processed 100 videos, running average time/pair: 4.62 sec
#   Processed 110 videos, running average time/pair: 4.73 sec
#   Processed 120 videos, running average time/pair: 5.53 sec
#   Processed 130 videos, running average time/pair: 5.42 sec
#   Processed 140 videos, running average time/pair: 5.00 sec
#   Processed 150 videos, running average time/pair: 4.73 sec
#   Processed 160 videos, running average time/pair: 4.52 sec
#   Total process time: 14.34 min
# Preprocessing epoch block 343:
#   Processed 10 videos, running average time/pair: 5.45 sec
#   Processed 20 videos, running average time/pair: 5.55 sec
#   Processed 30 videos, running average time/pair: 5.26 sec
#   Processed 40 videos, running average time/pair: 4.90 sec
#   Processed 50 videos, running average time/pair: 5.23 sec
#   Processed 60 videos, running average time/pair: 4.87 sec
#   Processed 70 videos, running average time/pair: 5.47 sec
#   Processed 80 videos, running average time/pair: 5.30 sec
#   Processed 90 videos, running average time/pair: 5.26 sec
#   Processed 100 videos, running average time/pair: 4.92 sec
#   Processed 110 videos, running average time/pair: 5.77 sec
#   Processed 120 videos, running average time/pair: 5.02 sec
#   Processed 130 videos, running average time/pair: 5.57 sec
#   Processed 140 videos, running average time/pair: 5.14 sec
#   Processed 150 videos, running average time/pair: 5.02 sec
#   Processed 160 videos, running average time/pair: 4.40 sec
#   Processed 170 videos, running average time/pair: 4.85 sec
#   Total process time: 14.74 min
# Preprocessing epoch block 350:
#   Processed 10 videos, running average time/pair: 4.70 sec
#   Processed 20 videos, running average time/pair: 4.65 sec
#   Processed 30 videos, running average time/pair: 4.87 sec
#   Processed 40 videos, running average time/pair: 5.61 sec
#   Processed 50 videos, running average time/pair: 5.62 sec
#   Processed 60 videos, running average time/pair: 5.14 sec
#   Processed 70 videos, running average time/pair: 5.21 sec
#   Processed 80 videos, running average time/pair: 4.87 sec
#   Processed 90 videos, running average time/pair: 4.86 sec
#   Processed 100 videos, running average time/pair: 5.52 sec
#   Processed 110 videos, running average time/pair: 5.69 sec
#   Processed 120 videos, running average time/pair: 4.45 sec
#   Processed 130 videos, running average time/pair: 4.66 sec
#   Processed 140 videos, running average time/pair: 4.73 sec
#   Processed 150 videos, running average time/pair: 4.53 sec
#   Processed 160 videos, running average time/pair: 5.24 sec
#   Total process time: 13.39 min
# Preprocessing epoch block 557:
#   Processed 10 videos, running average time/pair: 4.94 sec
#   Processed 20 videos, running average time/pair: 5.66 sec
#   Processed 30 videos, running average time/pair: 4.84 sec
#   Processed 40 videos, running average time/pair: 4.93 sec
#   Processed 50 videos, running average time/pair: 4.82 sec
#   Processed 60 videos, running average time/pair: 4.48 sec
#   Processed 70 videos, running average time/pair: 5.11 sec
#   Processed 80 videos, running average time/pair: 5.09 sec
#   Processed 90 videos, running average time/pair: 5.47 sec
#   Processed 100 videos, running average time/pair: 5.26 sec
#   Processed 110 videos, running average time/pair: 5.06 sec
#   Processed 120 videos, running average time/pair: 4.66 sec
#   Processed 130 videos, running average time/pair: 5.06 sec
#   Processed 140 videos, running average time/pair: 4.94 sec
#   Processed 150 videos, running average time/pair: 4.76 sec
#   Processed 160 videos, running average time/pair: 5.40 sec
#   Processed 170 videos, running average time/pair: 5.45 sec
#   Total process time: 14.32 min
# Preprocessing epoch block 194:
#   Processed 10 videos, running average time/pair: 5.03 sec
#   Processed 20 videos, running average time/pair: 5.21 sec
#   Processed 30 videos, running average time/pair: 5.01 sec
#   Processed 40 videos, running average time/pair: 4.75 sec
#   Processed 50 videos, running average time/pair: 5.68 sec
#   Processed 60 videos, running average time/pair: 5.88 sec
#   Processed 70 videos, running average time/pair: 5.01 sec
#   Processed 80 videos, running average time/pair: 5.03 sec
#   Processed 90 videos, running average time/pair: 4.84 sec
#   Processed 100 videos, running average time/pair: 5.23 sec
#   Processed 110 videos, running average time/pair: 5.39 sec
#   Processed 120 videos, running average time/pair: 5.32 sec
#   Processed 130 videos, running average time/pair: 4.55 sec
#   Processed 140 videos, running average time/pair: 4.61 sec
#   Processed 150 videos, running average time/pair: 5.01 sec
#   Processed 160 videos, running average time/pair: 4.73 sec
#   Processed 170 videos, running average time/pair: 4.57 sec
#   Processed 180 videos, running average time/pair: 4.55 sec
#   Total process time: 15.14 min
# Preprocessing epoch block 218:
#   Processed 10 videos, running average time/pair: 5.21 sec
#   Processed 20 videos, running average time/pair: 5.41 sec
#   Processed 30 videos, running average time/pair: 5.11 sec
#   Processed 40 videos, running average time/pair: 4.80 sec
#   Processed 50 videos, running average time/pair: 4.90 sec
#   Processed 60 videos, running average time/pair: 5.37 sec
#   Processed 70 videos, running average time/pair: 5.41 sec
#   Processed 80 videos, running average time/pair: 4.75 sec
#   Processed 90 videos, running average time/pair: 4.64 sec
#   Processed 100 videos, running average time/pair: 4.21 sec
#   Processed 110 videos, running average time/pair: 4.70 sec
#   Processed 120 videos, running average time/pair: 4.66 sec
#   Processed 130 videos, running average time/pair: 4.34 sec
#   Processed 140 videos, running average time/pair: 4.91 sec
#   Processed 150 videos, running average time/pair: 5.44 sec
#   Processed 160 videos, running average time/pair: 5.17 sec
#   Total process time: 13.83 min
# Preprocessing epoch block 356:
#   Processed 10 videos, running average time/pair: 4.98 sec
#   Processed 20 videos, running average time/pair: 4.91 sec
#   Processed 30 videos, running average time/pair: 5.33 sec
#   Processed 40 videos, running average time/pair: 5.62 sec
#   Processed 50 videos, running average time/pair: 5.45 sec
#   Processed 60 videos, running average time/pair: 4.89 sec
#   Processed 70 videos, running average time/pair: 4.99 sec
#   Processed 80 videos, running average time/pair: 5.18 sec
#   Processed 90 videos, running average time/pair: 5.21 sec
#   Processed 100 videos, running average time/pair: 5.58 sec
#   Processed 110 videos, running average time/pair: 5.22 sec
#   Processed 120 videos, running average time/pair: 5.10 sec
#   Processed 130 videos, running average time/pair: 5.13 sec
#   Processed 140 videos, running average time/pair: 5.18 sec
#   Processed 150 videos, running average time/pair: 5.05 sec
#   Processed 160 videos, running average time/pair: 5.64 sec
#   Processed 170 videos, running average time/pair: 5.19 sec
#   Total process time: 15.10 min
# Preprocessing epoch block 191:
#   Processed 10 videos, running average time/pair: 4.44 sec
#   Processed 20 videos, running average time/pair: 4.58 sec
#   Processed 30 videos, running average time/pair: 4.99 sec
#   Processed 40 videos, running average time/pair: 4.70 sec
#   Processed 50 videos, running average time/pair: 4.92 sec
#   Processed 60 videos, running average time/pair: 5.28 sec
#   Processed 70 videos, running average time/pair: 5.63 sec
#   Processed 80 videos, running average time/pair: 4.91 sec
#   Processed 90 videos, running average time/pair: 4.61 sec
#   Processed 100 videos, running average time/pair: 4.88 sec
#   Processed 110 videos, running average time/pair: 4.62 sec
#   Processed 120 videos, running average time/pair: 5.72 sec
#   Processed 130 videos, running average time/pair: 5.57 sec
#   Processed 140 videos, running average time/pair: 4.89 sec
#   Processed 150 videos, running average time/pair: 5.07 sec
#   Processed 160 videos, running average time/pair: 4.97 sec
#   Total process time: 13.86 min
# Preprocessing epoch block 444:
#   Processed 10 videos, running average time/pair: 5.54 sec
#   Processed 20 videos, running average time/pair: 5.49 sec
#   Processed 30 videos, running average time/pair: 5.03 sec
#   Processed 40 videos, running average time/pair: 4.75 sec
#   Processed 50 videos, running average time/pair: 4.44 sec
#   Processed 60 videos, running average time/pair: 5.16 sec
#   Processed 70 videos, running average time/pair: 5.53 sec
#   Processed 80 videos, running average time/pair: 5.61 sec
#   Processed 90 videos, running average time/pair: 4.58 sec
#   Processed 100 videos, running average time/pair: 4.62 sec
#   Processed 110 videos, running average time/pair: 4.93 sec
#   Processed 120 videos, running average time/pair: 4.76 sec
#   Processed 130 videos, running average time/pair: 4.62 sec
#   Processed 140 videos, running average time/pair: 4.98 sec
#   Processed 150 videos, running average time/pair: 5.11 sec
#   Processed 160 videos, running average time/pair: 5.27 sec
#   Processed 170 videos, running average time/pair: 5.14 sec
#   Total process time: 14.69 min
# Preprocessing epoch block 493:
#   Processed 10 videos, running average time/pair: 4.82 sec
#   Processed 20 videos, running average time/pair: 4.84 sec
#   Processed 30 videos, running average time/pair: 5.31 sec
#   Processed 40 videos, running average time/pair: 5.63 sec
#   Processed 50 videos, running average time/pair: 4.94 sec
#   Processed 60 videos, running average time/pair: 4.44 sec
#   Processed 70 videos, running average time/pair: 4.55 sec
#   Processed 80 videos, running average time/pair: 5.06 sec
#   Processed 90 videos, running average time/pair: 5.24 sec
#   Processed 100 videos, running average time/pair: 5.41 sec
#   Processed 110 videos, running average time/pair: 5.00 sec
#   Processed 120 videos, running average time/pair: 4.45 sec
#   Processed 130 videos, running average time/pair: 4.66 sec
#   Processed 140 videos, running average time/pair: 4.56 sec
#   Processed 150 videos, running average time/pair: 4.56 sec
#   Total process time: 12.58 min
# Preprocessing epoch block 278:
#   Processed 10 videos, running average time/pair: 4.67 sec
#   Processed 20 videos, running average time/pair: 5.29 sec
#   Processed 30 videos, running average time/pair: 5.48 sec
#   Processed 40 videos, running average time/pair: 4.56 sec
#   Processed 50 videos, running average time/pair: 4.88 sec
#   Processed 60 videos, running average time/pair: 4.68 sec
#   Processed 70 videos, running average time/pair: 4.77 sec
#   Processed 80 videos, running average time/pair: 5.14 sec
#   Processed 90 videos, running average time/pair: 5.51 sec
#   Processed 100 videos, running average time/pair: 4.96 sec
#   Processed 110 videos, running average time/pair: 4.77 sec
#   Processed 120 videos, running average time/pair: 4.95 sec
#   Processed 130 videos, running average time/pair: 4.94 sec
#   Processed 140 videos, running average time/pair: 5.06 sec
#   Processed 150 videos, running average time/pair: 5.45 sec
#   Processed 160 videos, running average time/pair: 5.22 sec
#   Processed 170 videos, running average time/pair: 4.48 sec
#   Total process time: 14.14 min
# Preprocessing epoch block 541:
#   Processed 10 videos, running average time/pair: 4.50 sec
#   Processed 20 videos, running average time/pair: 4.80 sec
#   Processed 30 videos, running average time/pair: 4.64 sec
#   Processed 40 videos, running average time/pair: 4.11 sec
#   Processed 50 videos, running average time/pair: 5.28 sec
#   Processed 60 videos, running average time/pair: 5.62 sec
#   Processed 70 videos, running average time/pair: 5.20 sec
#   Processed 80 videos, running average time/pair: 4.70 sec
#   Processed 90 videos, running average time/pair: 4.83 sec
#   Processed 100 videos, running average time/pair: 4.84 sec
#   Processed 110 videos, running average time/pair: 5.25 sec
#   Processed 120 videos, running average time/pair: 5.67 sec
#   Processed 130 videos, running average time/pair: 4.91 sec
#   Processed 140 videos, running average time/pair: 4.57 sec
#   Processed 150 videos, running average time/pair: 4.81 sec
#   Processed 160 videos, running average time/pair: 4.57 sec
#   Processed 170 videos, running average time/pair: 4.67 sec
#   Total process time: 14.14 min
# Preprocessing epoch block 504:
#   Processed 10 videos, running average time/pair: 4.76 sec
#   Processed 20 videos, running average time/pair: 5.45 sec
#   Processed 30 videos, running average time/pair: 5.15 sec
#   Processed 40 videos, running average time/pair: 4.50 sec
#   Processed 50 videos, running average time/pair: 4.99 sec
#   Processed 60 videos, running average time/pair: 4.91 sec
#   Processed 70 videos, running average time/pair: 4.84 sec
#   Processed 80 videos, running average time/pair: 5.24 sec
#   Processed 90 videos, running average time/pair: 5.19 sec
#   Processed 100 videos, running average time/pair: 4.86 sec
#   Processed 110 videos, running average time/pair: 4.65 sec
#   Processed 120 videos, running average time/pair: 4.64 sec
#   Processed 130 videos, running average time/pair: 4.70 sec
#   Processed 140 videos, running average time/pair: 4.74 sec
#   Processed 150 videos, running average time/pair: 4.73 sec
#   Processed 160 videos, running average time/pair: 5.52 sec
#   Total process time: 13.69 min
# Preprocessing epoch block 66:
#   Processed 10 videos, running average time/pair: 5.18 sec
#   Processed 20 videos, running average time/pair: 4.63 sec
#   Processed 30 videos, running average time/pair: 4.65 sec
#   Processed 40 videos, running average time/pair: 5.08 sec
#   Processed 50 videos, running average time/pair: 5.17 sec
#   Processed 60 videos, running average time/pair: 5.52 sec
#   Processed 70 videos, running average time/pair: 4.93 sec
#   Processed 80 videos, running average time/pair: 4.85 sec
#   Processed 90 videos, running average time/pair: 4.73 sec
#   Processed 100 videos, running average time/pair: 4.48 sec
#   Processed 110 videos, running average time/pair: 4.84 sec
#   Processed 120 videos, running average time/pair: 4.58 sec
#   Processed 130 videos, running average time/pair: 5.21 sec
#   Processed 140 videos, running average time/pair: 5.33 sec
#   Processed 150 videos, running average time/pair: 5.28 sec
#   Processed 160 videos, running average time/pair: 4.67 sec
#   Total process time: 13.50 min
# Preprocessing epoch block 162:
#   Total process time: 0.00 min
# Preprocessing epoch block 318:
#   Processed 10 videos, running average time/pair: 4.52 sec
#   Processed 20 videos, running average time/pair: 4.59 sec
#   Processed 30 videos, running average time/pair: 4.44 sec
#   Processed 40 videos, running average time/pair: 4.58 sec
#   Processed 50 videos, running average time/pair: 5.39 sec
#   Processed 60 videos, running average time/pair: 5.29 sec
#   Processed 70 videos, running average time/pair: 5.11 sec
#   Processed 80 videos, running average time/pair: 4.74 sec
#   Processed 90 videos, running average time/pair: 4.78 sec
#   Processed 100 videos, running average time/pair: 4.93 sec
#   Processed 110 videos, running average time/pair: 5.31 sec
#   Processed 120 videos, running average time/pair: 5.12 sec
#   Processed 130 videos, running average time/pair: 5.29 sec
#   Processed 140 videos, running average time/pair: 4.52 sec
#   Processed 150 videos, running average time/pair: 4.74 sec
#   Processed 160 videos, running average time/pair: 4.33 sec
#   Total process time: 13.16 min
# Preprocessing epoch block 225:
#   Processed 10 videos, running average time/pair: 4.60 sec
#   Processed 20 videos, running average time/pair: 5.14 sec
#   Processed 30 videos, running average time/pair: 5.45 sec
#   Processed 40 videos, running average time/pair: 5.14 sec
#   Processed 50 videos, running average time/pair: 5.04 sec
#   Processed 60 videos, running average time/pair: 5.06 sec
#   Processed 70 videos, running average time/pair: 5.47 sec
#   Processed 80 videos, running average time/pair: 5.19 sec
#   Processed 90 videos, running average time/pair: 5.48 sec
#   Processed 100 videos, running average time/pair: 5.77 sec
#   Processed 110 videos, running average time/pair: 4.84 sec
#   Processed 120 videos, running average time/pair: 4.81 sec
#   Processed 130 videos, running average time/pair: 4.64 sec
#   Processed 140 videos, running average time/pair: 4.50 sec
#   Processed 150 videos, running average time/pair: 4.22 sec
#   Processed 160 videos, running average time/pair: 4.96 sec
#   Total process time: 13.73 min
# Preprocessing epoch block 11:
#   Processed 10 videos, running average time/pair: 5.19 sec
#   Processed 20 videos, running average time/pair: 4.84 sec
#   Processed 30 videos, running average time/pair: 4.50 sec
#   Processed 40 videos, running average time/pair: 4.88 sec
#   Processed 50 videos, running average time/pair: 4.84 sec
#   Processed 60 videos, running average time/pair: 4.86 sec
#   Processed 70 videos, running average time/pair: 5.30 sec
#   Processed 80 videos, running average time/pair: 5.35 sec
#   Processed 90 videos, running average time/pair: 5.08 sec
#   Processed 100 videos, running average time/pair: 5.01 sec
#   Processed 110 videos, running average time/pair: 5.06 sec
#   Processed 120 videos, running average time/pair: 4.54 sec
#   Processed 130 videos, running average time/pair: 4.85 sec
#   Processed 140 videos, running average time/pair: 5.40 sec
#   Processed 150 videos, running average time/pair: 5.39 sec
#   Processed 160 videos, running average time/pair: 5.30 sec
#   Total process time: 14.06 min
# Preprocessing epoch block 219:
#   Processed 10 videos, running average time/pair: 5.13 sec
#   Processed 20 videos, running average time/pair: 5.26 sec
#   Processed 30 videos, running average time/pair: 5.33 sec
#   Processed 40 videos, running average time/pair: 5.42 sec
#   Processed 50 videos, running average time/pair: 5.26 sec
#   Processed 60 videos, running average time/pair: 5.04 sec
#   Processed 70 videos, running average time/pair: 4.75 sec
#   Processed 80 videos, running average time/pair: 4.71 sec
#   Processed 90 videos, running average time/pair: 5.18 sec
#   Processed 100 videos, running average time/pair: 5.42 sec
#   Processed 110 videos, running average time/pair: 5.42 sec
#   Processed 120 videos, running average time/pair: 5.10 sec
#   Processed 130 videos, running average time/pair: 4.89 sec
#   Processed 140 videos, running average time/pair: 4.90 sec
#   Processed 150 videos, running average time/pair: 5.38 sec
#   Processed 160 videos, running average time/pair: 5.33 sec
#   Total process time: 14.29 min
# Preprocessing epoch block 509:
#   Processed 10 videos, running average time/pair: 4.85 sec
#   Processed 20 videos, running average time/pair: 5.04 sec
#   Processed 30 videos, running average time/pair: 4.79 sec
#   Processed 40 videos, running average time/pair: 5.25 sec
#   Processed 50 videos, running average time/pair: 5.91 sec
#   Processed 60 videos, running average time/pair: 4.99 sec
#   Processed 70 videos, running average time/pair: 4.88 sec
#   Processed 80 videos, running average time/pair: 4.90 sec
#   Processed 90 videos, running average time/pair: 4.99 sec
#   Processed 100 videos, running average time/pair: 5.47 sec
#   Processed 110 videos, running average time/pair: 5.40 sec
#   Processed 120 videos, running average time/pair: 5.18 sec
#   Processed 130 videos, running average time/pair: 4.47 sec
#   Processed 140 videos, running average time/pair: 4.55 sec
#   Processed 150 videos, running average time/pair: 4.46 sec
#   Processed 160 videos, running average time/pair: 4.56 sec
#   Processed 170 videos, running average time/pair: 4.23 sec
#   Total process time: 14.40 min
# Preprocessing epoch block 254:
#   Processed 10 videos, running average time/pair: 5.50 sec
#   Processed 20 videos, running average time/pair: 5.43 sec
#   Processed 30 videos, running average time/pair: 4.99 sec
#   Processed 40 videos, running average time/pair: 4.91 sec
#   Processed 50 videos, running average time/pair: 4.63 sec
#   Processed 60 videos, running average time/pair: 4.91 sec
#   Processed 70 videos, running average time/pair: 5.55 sec
#   Processed 80 videos, running average time/pair: 5.65 sec
#   Processed 90 videos, running average time/pair: 4.70 sec
#   Processed 100 videos, running average time/pair: 4.84 sec
#   Processed 110 videos, running average time/pair: 5.00 sec
#   Processed 120 videos, running average time/pair: 5.22 sec
#   Processed 130 videos, running average time/pair: 5.70 sec
#   Processed 140 videos, running average time/pair: 5.05 sec
#   Processed 150 videos, running average time/pair: 4.69 sec
#   Processed 160 videos, running average time/pair: 4.68 sec
#   Total process time: 13.70 min
# Preprocessing epoch block 108:
#   Processed 10 videos, running average time/pair: 4.68 sec
#   Processed 20 videos, running average time/pair: 4.50 sec
#   Processed 30 videos, running average time/pair: 4.54 sec
#   Processed 40 videos, running average time/pair: 5.52 sec
#   Processed 50 videos, running average time/pair: 5.41 sec
#   Processed 60 videos, running average time/pair: 5.05 sec
#   Processed 70 videos, running average time/pair: 4.59 sec
#   Processed 80 videos, running average time/pair: 4.76 sec
#   Processed 90 videos, running average time/pair: 4.91 sec
#   Processed 100 videos, running average time/pair: 5.16 sec
#   Processed 110 videos, running average time/pair: 5.28 sec
#   Processed 120 videos, running average time/pair: 5.18 sec
#   Processed 130 videos, running average time/pair: 4.72 sec
#   Processed 140 videos, running average time/pair: 5.10 sec
#   Processed 150 videos, running average time/pair: 4.72 sec
#   Processed 160 videos, running average time/pair: 5.57 sec
#   Total process time: 13.78 min
# Preprocessing epoch block 79:
#   Total process time: 0.00 min
# Preprocessing epoch block 38:
#   Processed 10 videos, running average time/pair: 5.32 sec
#   Processed 20 videos, running average time/pair: 4.93 sec
#   Processed 30 videos, running average time/pair: 4.68 sec
#   Processed 40 videos, running average time/pair: 4.50 sec
#   Processed 50 videos, running average time/pair: 5.22 sec
#   Processed 60 videos, running average time/pair: 5.30 sec
#   Processed 70 videos, running average time/pair: 5.39 sec
#   Processed 80 videos, running average time/pair: 4.87 sec
#   Processed 90 videos, running average time/pair: 4.52 sec
#   Processed 100 videos, running average time/pair: 4.79 sec
#   Processed 110 videos, running average time/pair: 4.96 sec
#   Processed 120 videos, running average time/pair: 4.70 sec
#   Processed 130 videos, running average time/pair: 5.57 sec
#   Processed 140 videos, running average time/pair: 5.70 sec
#   Processed 150 videos, running average time/pair: 5.28 sec
#   Processed 160 videos, running average time/pair: 4.65 sec
#   Total process time: 13.61 min
# Preprocessing epoch block 491:
#   Processed 10 videos, running average time/pair: 4.60 sec
#   Processed 20 videos, running average time/pair: 4.82 sec
#   Processed 30 videos, running average time/pair: 4.54 sec
#   Processed 40 videos, running average time/pair: 4.96 sec
#   Processed 50 videos, running average time/pair: 5.11 sec
#   Processed 60 videos, running average time/pair: 5.32 sec
#   Processed 70 videos, running average time/pair: 4.91 sec
#   Processed 80 videos, running average time/pair: 5.02 sec
#   Processed 90 videos, running average time/pair: 4.70 sec
#   Processed 100 videos, running average time/pair: 5.12 sec
#   Processed 110 videos, running average time/pair: 5.43 sec
#   Processed 120 videos, running average time/pair: 5.20 sec
#   Processed 130 videos, running average time/pair: 4.62 sec
#   Processed 140 videos, running average time/pair: 4.77 sec
#   Processed 150 videos, running average time/pair: 4.48 sec
#   Processed 160 videos, running average time/pair: 4.56 sec
#   Total process time: 13.66 min
# Preprocessing epoch block 194:
#   Total process time: 0.00 min
# Preprocessing epoch block 300:
#   Processed 10 videos, running average time/pair: 4.96 sec
#   Processed 20 videos, running average time/pair: 4.63 sec
#   Processed 30 videos, running average time/pair: 5.27 sec
#   Processed 40 videos, running average time/pair: 4.76 sec
#   Processed 50 videos, running average time/pair: 4.76 sec
#   Processed 60 videos, running average time/pair: 4.71 sec
#   Processed 70 videos, running average time/pair: 4.77 sec
#   Processed 80 videos, running average time/pair: 5.40 sec
#   Processed 90 videos, running average time/pair: 5.14 sec
#   Processed 100 videos, running average time/pair: 5.05 sec
#   Processed 110 videos, running average time/pair: 4.78 sec
#   Processed 120 videos, running average time/pair: 4.64 sec
#   Processed 130 videos, running average time/pair: 4.99 sec
#   Processed 140 videos, running average time/pair: 5.34 sec
#   Processed 150 videos, running average time/pair: 5.46 sec
#   Processed 160 videos, running average time/pair: 4.83 sec
#   Total process time: 13.25 min
# Preprocessing epoch block 62:
#   Processed 10 videos, running average time/pair: 4.41 sec
#   Processed 20 videos, running average time/pair: 4.53 sec
#   Processed 30 videos, running average time/pair: 4.78 sec
#   Processed 40 videos, running average time/pair: 4.63 sec
#   Processed 50 videos, running average time/pair: 4.47 sec
#   Processed 60 videos, running average time/pair: 5.25 sec
#   Processed 70 videos, running average time/pair: 5.40 sec
#   Processed 80 videos, running average time/pair: 5.14 sec
#   Processed 90 videos, running average time/pair: 5.08 sec
#   Processed 100 videos, running average time/pair: 5.04 sec
#   Processed 110 videos, running average time/pair: 4.45 sec
#   Processed 120 videos, running average time/pair: 5.39 sec
#   Processed 130 videos, running average time/pair: 5.59 sec
#   Processed 140 videos, running average time/pair: 4.95 sec
#   Processed 150 videos, running average time/pair: 5.28 sec
#   Processed 160 videos, running average time/pair: 4.80 sec
#   Total process time: 13.75 min
# Preprocessing epoch block 550:
#   Total process time: 0.00 min
# Preprocessing epoch block 440:
#   Processed 10 videos, running average time/pair: 5.38 sec
#   Processed 20 videos, running average time/pair: 5.00 sec
#   Processed 30 videos, running average time/pair: 5.15 sec
#   Processed 40 videos, running average time/pair: 4.93 sec
#   Processed 50 videos, running average time/pair: 4.81 sec
#   Processed 60 videos, running average time/pair: 5.04 sec
#   Processed 70 videos, running average time/pair: 5.20 sec
#   Processed 80 videos, running average time/pair: 5.57 sec
#   Processed 90 videos, running average time/pair: 5.11 sec
#   Processed 100 videos, running average time/pair: 5.04 sec
#   Processed 110 videos, running average time/pair: 5.12 sec
#   Processed 120 videos, running average time/pair: 4.94 sec
#   Processed 130 videos, running average time/pair: 5.53 sec
#   Processed 140 videos, running average time/pair: 5.47 sec
#   Processed 150 videos, running average time/pair: 4.52 sec
#   Processed 160 videos, running average time/pair: 4.60 sec
#   Total process time: 13.74 min
# Preprocessing epoch block 369:
#   Processed 10 videos, running average time/pair: 4.62 sec
#   Processed 20 videos, running average time/pair: 4.81 sec
#   Processed 30 videos, running average time/pair: 4.61 sec
#   Processed 40 videos, running average time/pair: 4.72 sec
#   Processed 50 videos, running average time/pair: 5.61 sec
#   Processed 60 videos, running average time/pair: 5.33 sec
#   Processed 70 videos, running average time/pair: 5.19 sec
#   Processed 80 videos, running average time/pair: 4.83 sec
#   Processed 90 videos, running average time/pair: 4.89 sec
#   Processed 100 videos, running average time/pair: 4.60 sec
#   Processed 110 videos, running average time/pair: 5.17 sec
#   Processed 120 videos, running average time/pair: 5.79 sec
#   Processed 130 videos, running average time/pair: 5.04 sec
#   Processed 140 videos, running average time/pair: 4.85 sec
#   Processed 150 videos, running average time/pair: 4.80 sec
#   Processed 160 videos, running average time/pair: 5.21 sec
#   Processed 170 videos, running average time/pair: 5.71 sec
#   Total process time: 14.80 min
# Preprocessing epoch block 509:
#   Total process time: 0.00 min
# Preprocessing epoch block 51:
#   Processed 10 videos, running average time/pair: 4.93 sec
#   Processed 20 videos, running average time/pair: 5.01 sec
#   Processed 30 videos, running average time/pair: 4.71 sec
#   Processed 40 videos, running average time/pair: 4.73 sec
#   Processed 50 videos, running average time/pair: 5.36 sec
#   Processed 60 videos, running average time/pair: 5.17 sec
#   Processed 70 videos, running average time/pair: 4.28 sec
#   Processed 80 videos, running average time/pair: 3.28 sec
#   Processed 90 videos, running average time/pair: 3.38 sec
#   Processed 100 videos, running average time/pair: 3.44 sec
#   Processed 110 videos, running average time/pair: 3.75 sec
#   Processed 120 videos, running average time/pair: 3.50 sec
#   Processed 130 videos, running average time/pair: 3.72 sec
#   Processed 140 videos, running average time/pair: 3.69 sec
#   Processed 150 videos, running average time/pair: 3.43 sec
#   Total process time: 10.83 min

# %%
# This fcn takes just an initial glance at the video and metadata
# in the training set and prints out some informational metrics.
def summarize_data(istart, istop=None, netsum=True, verbose=False):
#{
    # Like range args
    if istop is None:
        istart, istop = 0, istart

    summation = []
    for i in range(istart, istop):
    #{
        try:
        #{
            numvids, numtrain, vidsfounds, numfakes, origfound = 0,0,0,0,0
            with open(f"{df.traindir(i)}/metadata.json") as jsonfile:
            #{
                metadata = json.load(jsonfile)
                for vidname, meta in metadata.items():
                #{
                    vname = f"{df.traindir(i)}/{vidname}"
                    numvids += 1

                    if meta['split'] == 'train': numtrain += 1
                    if df.file_exists(vname): vidsfounds += 1

                    if (meta['label'] == 'FAKE'):
                        oname = f"{df.traindir(i)}/{meta['original']}"
                        if df.file_exists(oname): origfound += 1
                        numfakes += 1
                #}
            #}
        #}
        except PermissionError as err: print("ERROR:", err)
        
        if verbose:
            print(f"Partition: {df.trainpart(i)}:")
            print(f"  Numb of primary video meta-references/train split: {numvids}/{numtrain}")
            print(f"  Numb of actual primary videos files found on disk: {vidsfounds}")
            print(f"  Numb of fake/original meta-pairs: {numfakes}")
            print(f"  Numb of actual video pairs found on disk: {origfound}")
            
        if (numvids != vidsfounds) or (numvids != numtrain) or (numfakes != origfound):
            print(f"  DISCREPENCY found in partition {df.trainpart(i)}")
            
        if netsum: summation.append((numvids, numtrain, vidsfounds, numfakes, origfound))
    #}
    
    if netsum:
    #{
        numvids, numtrain, vidsfounds, numfakes, origfound = functools.reduce(
            lambda st1, st2: (st1[0]+st2[0], st1[1]+st2[1], st1[2]+st2[2], 
                              st1[3]+st2[3], st1[4]+st2[4]), summation)
        
        print(f"\nNet dataset summary:")
        print(f"  Numb of primary video meta-references/train split: {numvids}/{numtrain}")
        print(f"  Numb of actual primary videos files found on disk: {vidsfounds}")
        print(f"  Numb of fake/original meta-pairs: {numfakes}")
        print(f"  Numb of actual video pairs found on disk: {origfound}\n")
    #}
#}

if dfc.DATA_SOURCE == 'production':
#{
    summarize_data(50, verbose=False)

    # Partitions 18 and 35 appear slightly incomplete.
    # summarize_data(18, 19, netsum=False, verbose=True)
    # summarize_data(35, 36, netsum=False, verbose=True)
#}
elif dfc.DATA_SOURCE == 'sample': 
    summarize_data(1, verbose=True)

# %%
# %%time

# Generates video pairs from metadata file, defines a datapath per
# pair, and generates fakerframes and fakerprint for that pair.
def preprocess_data(istart=1, istop=None, batchsz=10):
#{
    if istop is None: istart, istop = 0, istart

    batchtimes, batchnum = [], 1
    for i in range(istart, istop):
    #{
        parttime = time.time()
        fpairs = df.faked_video_pairs(i)
        if not os.path.isdir(df.fakerdir(i)): os.mkdir(df.fakerdir(i))
        print(f"Preprocessing {len(fpairs)} video pairs in partition {df.trainpart(i)}:")
        for j, pc_pair in enumerate(fpairs):
        #{
            # This is some finagled code to pickup somewhere mid-partition
            #if re.split(r'[/.]', pc_pair[0])[-2] == 'wmoigsbnem': pickup = True
            #if not pickup: continue
        
            batchtimes.append(time.time())
            datapath = f"{df.fakerdir(i)}/{re.split(r'[/.]', pc_pair[0])[-2]}"
            if not os.path.isdir(datapath): os.mkdir(datapath)
            df.create_diff_frames(pc_pair[0], pc_pair[1], datapath)
            
            batchtimes[-1] = time.time() - batchtimes[-1]
            if len(batchtimes) == batchsz:
                print(f"  Average preprocess time per pair for batch {batchnum}: {np.average(batchtimes):.2f} sec")
                batchnum += 1; batchtimes = []
        #}
        print(f"  Total partition {df.trainpart(i)} preprocessing time: {(time.time()-parttime):.2f} sec")
    #}
#}

if dfc.DATA_SOURCE == 'sample':
    preprocess_data()

elif dfc.DATA_SOURCE == 'production': 
#{
    # With no arguments, preprocesses just the first partition (1334 videos). 
    # On my iMac, this averaged ~28 sec/video (or 10.5 hrs total).
    preprocess_data()
#}

# %%
# Just copies all the fakerprints into a single 
# for directory testing/debugging purposes

import shutil

dirlist = !ls -tr1 {df.fakerdir()}
for i, dfile in enumerate(dirlist): 
    shutil.copyfile(f"{df.fakerdir()}/{dfile}/fakerprint.jpg",
                    f"{df.fakerdir()}/../fakerprints/fakerprint{i}.jpg")
