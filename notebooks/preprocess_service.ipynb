# %% [markdown]
# # Deepfake Data Preprocessor
#
# This Notebook is for preprocessing the training data, i.e. (currently anyway) creating difference-blend-mode image files
# for every frame of the faked video, plus a final "fakerprint" image (see comments below). You should be able to preprocess
# kaggle's little sample dataset in only like 20 minutes. This video player: https://darbyjohnston.github.io/DJV/ can play
# the JPG difference-image sequences as if they were a video if you want (Premiere can do this too, but not Quicktime).
#
# Make sure to correctly set the **DATA_LAKE** below before preprocessing (and **run_sample_data** flag if apropos).
#
# #### Main Function Table of Contents:
# + **summarize_data()** - Just has a tertiary look at the dataset and prints out some metrics.
# + **create_fakerframes_cv2()** - Creates the actual difference and fakerprint image files.
# + **preprocess_data()** - Orchestrates calls to faked_video_pairs() and create_fakerframes_cv2() on the dataset.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os, re, time
import functools
import cv2, json
import numpy as np

# For managing relative imports from notebook
if '..' not in sys.path: sys.path.append('..')

import config.config as dfc
import deepfake.dfutillib as df
import deepfake.preprocessor as dproc

# %%
dproc.Preprocessor(minqueued=None).run()
# Out:
# Preprocessing epoch block 426:
#   Total process time: 0.00 min
# Preprocessing epoch block 382:
#   Processed 10 videos, running average time/pair: 4.17 sec
#   Processed 20 videos, running average time/pair: 3.53 sec
#   Processed 30 videos, running average time/pair: 3.84 sec
#   Processed 40 videos, running average time/pair: 3.98 sec
#   Processed 50 videos, running average time/pair: 3.70 sec
#   Processed 60 videos, running average time/pair: 3.89 sec
#   Processed 70 videos, running average time/pair: 3.97 sec
#   Processed 80 videos, running average time/pair: 3.94 sec
#   Processed 90 videos, running average time/pair: 3.75 sec
#   Processed 100 videos, running average time/pair: 3.71 sec
#   Processed 110 videos, running average time/pair: 3.54 sec
#   Processed 120 videos, running average time/pair: 3.71 sec
#   Processed 130 videos, running average time/pair: 3.73 sec
#   Processed 140 videos, running average time/pair: 4.05 sec
#   Processed 150 videos, running average time/pair: 3.61 sec
#   Total process time: 9.95 min
# Preprocessing epoch block 88:
#   Processed 10 videos, running average time/pair: 3.57 sec
#   Processed 20 videos, running average time/pair: 3.81 sec
#   Processed 30 videos, running average time/pair: 3.25 sec
#   Processed 40 videos, running average time/pair: 3.65 sec
#   Processed 50 videos, running average time/pair: 3.53 sec
#   Processed 60 videos, running average time/pair: 3.56 sec
#   Processed 70 videos, running average time/pair: 3.77 sec
#   Processed 80 videos, running average time/pair: 3.44 sec
#   Processed 90 videos, running average time/pair: 3.40 sec
#   Processed 100 videos, running average time/pair: 3.47 sec
#   Processed 110 videos, running average time/pair: 3.70 sec
#   Processed 120 videos, running average time/pair: 3.73 sec
#   Processed 130 videos, running average time/pair: 3.48 sec
#   Processed 140 videos, running average time/pair: 3.58 sec
#   Processed 150 videos, running average time/pair: 3.58 sec
#   Processed 160 videos, running average time/pair: 3.99 sec
#   Total process time: 10.12 min
# Preprocessing epoch block 587:
#   Processed 10 videos, running average time/pair: 3.55 sec
#   Processed 20 videos, running average time/pair: 3.77 sec
#   Processed 30 videos, running average time/pair: 3.60 sec
#   Processed 40 videos, running average time/pair: 3.72 sec
#   Processed 50 videos, running average time/pair: 3.65 sec
#   Processed 60 videos, running average time/pair: 3.68 sec
#   Processed 70 videos, running average time/pair: 4.02 sec
#   Processed 80 videos, running average time/pair: 3.41 sec
#   Processed 90 videos, running average time/pair: 3.72 sec
#   Processed 100 videos, running average time/pair: 3.67 sec
#   Processed 110 videos, running average time/pair: 3.57 sec
#   Processed 120 videos, running average time/pair: 3.31 sec
#   Processed 130 videos, running average time/pair: 3.75 sec
#   Processed 140 videos, running average time/pair: 3.76 sec
#   Processed 150 videos, running average time/pair: 3.43 sec
#   Processed 160 videos, running average time/pair: 3.87 sec
#   Total process time: 9.99 min
# Preprocessing epoch block 413:
#   Processed 10 videos, running average time/pair: 3.43 sec
#   Processed 20 videos, running average time/pair: 3.70 sec
#   Processed 30 videos, running average time/pair: 3.80 sec
#   Processed 40 videos, running average time/pair: 4.02 sec
#   Processed 50 videos, running average time/pair: 3.08 sec
#   Processed 60 videos, running average time/pair: 3.48 sec
#   Processed 70 videos, running average time/pair: 3.57 sec
#   Processed 80 videos, running average time/pair: 3.64 sec
#   Processed 90 videos, running average time/pair: 3.60 sec
#   Processed 100 videos, running average time/pair: 3.74 sec
#   Processed 110 videos, running average time/pair: 3.48 sec
#   Processed 120 videos, running average time/pair: 3.72 sec
#   Processed 130 videos, running average time/pair: 3.51 sec
#   Processed 140 videos, running average time/pair: 3.66 sec
#   Processed 150 videos, running average time/pair: 3.61 sec
#   Processed 160 videos, running average time/pair: 3.75 sec
#   Total process time: 9.70 min
# Preprocessing epoch block 421:
#   Processed 10 videos, running average time/pair: 3.77 sec
#   Processed 20 videos, running average time/pair: 3.88 sec
#   Processed 30 videos, running average time/pair: 3.75 sec
#   Processed 40 videos, running average time/pair: 3.86 sec
#   Processed 50 videos, running average time/pair: 3.32 sec
#   Processed 60 videos, running average time/pair: 3.43 sec
#   Processed 70 videos, running average time/pair: 3.62 sec
#   Processed 80 videos, running average time/pair: 3.59 sec
#   Processed 90 videos, running average time/pair: 3.96 sec
#   Processed 100 videos, running average time/pair: 3.43 sec
#   Processed 110 videos, running average time/pair: 3.79 sec
#   Processed 120 videos, running average time/pair: 3.90 sec
#   Processed 130 videos, running average time/pair: 3.51 sec
#   Processed 140 videos, running average time/pair: 3.61 sec
#   Processed 150 videos, running average time/pair: 4.23 sec
#   Processed 160 videos, running average time/pair: 3.71 sec
#   Total process time: 9.89 min
# Preprocessing epoch block 543:
#   Total process time: 0.00 min
# Preprocessing epoch block 217:
#   Processed 10 videos, running average time/pair: 3.36 sec
#   Processed 20 videos, running average time/pair: 3.50 sec
#   Processed 30 videos, running average time/pair: 3.21 sec
#   Processed 40 videos, running average time/pair: 3.45 sec
#   Processed 50 videos, running average time/pair: 3.32 sec
#   Processed 60 videos, running average time/pair: 3.40 sec
#   Processed 70 videos, running average time/pair: 3.39 sec
#   Processed 80 videos, running average time/pair: 3.47 sec
#   Processed 90 videos, running average time/pair: 3.39 sec
#   Processed 100 videos, running average time/pair: 3.30 sec
#   Processed 110 videos, running average time/pair: 3.61 sec
#   Processed 120 videos, running average time/pair: 3.37 sec
#   Processed 130 videos, running average time/pair: 3.46 sec
#   Processed 140 videos, running average time/pair: 3.26 sec
#   Processed 150 videos, running average time/pair: 3.35 sec
#   Processed 160 videos, running average time/pair: 3.51 sec
#   Total process time: 9.53 min
# Preprocessing epoch block 583:
#   Processed 10 videos, running average time/pair: 3.76 sec
#   Processed 20 videos, running average time/pair: 3.87 sec
#   Processed 30 videos, running average time/pair: 3.85 sec
#   Processed 40 videos, running average time/pair: 3.36 sec
#   Processed 50 videos, running average time/pair: 3.46 sec
#   Processed 60 videos, running average time/pair: 3.74 sec
#   Processed 70 videos, running average time/pair: 3.45 sec
#   Processed 80 videos, running average time/pair: 3.38 sec
#   Processed 90 videos, running average time/pair: 3.49 sec
#   Processed 100 videos, running average time/pair: 3.38 sec
#   Processed 110 videos, running average time/pair: 3.10 sec
#   Processed 120 videos, running average time/pair: 3.35 sec
#   Processed 130 videos, running average time/pair: 3.77 sec
#   Processed 140 videos, running average time/pair: 3.50 sec
#   Processed 150 videos, running average time/pair: 3.74 sec
#   Processed 160 videos, running average time/pair: 3.62 sec
#   Processed 170 videos, running average time/pair: 3.56 sec
#   Total process time: 10.07 min
# Preprocessing epoch block 349:
#   Processed 10 videos, running average time/pair: 3.54 sec
#   Processed 20 videos, running average time/pair: 3.05 sec
#   Processed 30 videos, running average time/pair: 3.25 sec
#   Processed 40 videos, running average time/pair: 3.30 sec
#   Processed 50 videos, running average time/pair: 3.68 sec
#   Processed 60 videos, running average time/pair: 3.49 sec
#   Processed 70 videos, running average time/pair: 3.59 sec
#   Processed 80 videos, running average time/pair: 3.53 sec
#   Processed 90 videos, running average time/pair: 3.50 sec
#   Processed 100 videos, running average time/pair: 3.50 sec
#   Processed 110 videos, running average time/pair: 3.64 sec
#   Processed 120 videos, running average time/pair: 3.39 sec
#   Processed 130 videos, running average time/pair: 3.34 sec
#   Processed 140 videos, running average time/pair: 3.29 sec
#   Processed 150 videos, running average time/pair: 3.42 sec
#   Processed 160 videos, running average time/pair: 3.61 sec
#   Processed 170 videos, running average time/pair: 3.32 sec
#   Total process time: 9.91 min
# Preprocessing epoch block 395:
#   Processed 10 videos, running average time/pair: 3.39 sec
#   Processed 20 videos, running average time/pair: 3.21 sec
#   Processed 30 videos, running average time/pair: 3.44 sec
#   Processed 40 videos, running average time/pair: 3.41 sec
#   Processed 50 videos, running average time/pair: 3.32 sec
#   Processed 60 videos, running average time/pair: 3.69 sec
#   Processed 70 videos, running average time/pair: 3.63 sec
#   Processed 80 videos, running average time/pair: 3.33 sec
#   Processed 90 videos, running average time/pair: 3.51 sec
#   Processed 100 videos, running average time/pair: 3.36 sec
#   Processed 110 videos, running average time/pair: 3.72 sec
#   Processed 120 videos, running average time/pair: 3.34 sec
#   Processed 130 videos, running average time/pair: 3.26 sec
#   Processed 140 videos, running average time/pair: 3.79 sec
#   Processed 150 videos, running average time/pair: 3.46 sec
#   Processed 160 videos, running average time/pair: 3.33 sec
#   Total process time: 9.68 min
# Preprocessing epoch block 487:
#   Processed 10 videos, running average time/pair: 3.32 sec
#   Processed 20 videos, running average time/pair: 3.43 sec
#   Processed 30 videos, running average time/pair: 3.44 sec
#   Processed 40 videos, running average time/pair: 3.15 sec
#   Processed 50 videos, running average time/pair: 3.72 sec
#   Processed 60 videos, running average time/pair: 3.54 sec
#   Processed 70 videos, running average time/pair: 3.56 sec
#   Processed 80 videos, running average time/pair: 3.42 sec
#   Processed 90 videos, running average time/pair: 3.17 sec
#   Processed 100 videos, running average time/pair: 3.79 sec
#   Processed 110 videos, running average time/pair: 3.44 sec
#   Processed 120 videos, running average time/pair: 3.60 sec
#   Processed 130 videos, running average time/pair: 3.55 sec
#   Processed 140 videos, running average time/pair: 3.48 sec
#   Processed 150 videos, running average time/pair: 3.15 sec
#   Processed 160 videos, running average time/pair: 4.37 sec
#   Total process time: 9.60 min
# Preprocessing epoch block 266:
#   Processed 10 videos, running average time/pair: 3.74 sec
#   Processed 20 videos, running average time/pair: 3.88 sec
#   Processed 30 videos, running average time/pair: 3.62 sec
#   Processed 40 videos, running average time/pair: 3.60 sec
#   Processed 50 videos, running average time/pair: 3.55 sec
#   Processed 60 videos, running average time/pair: 3.43 sec
#   Processed 70 videos, running average time/pair: 3.23 sec
#   Processed 80 videos, running average time/pair: 3.37 sec
#   Processed 90 videos, running average time/pair: 3.47 sec
#   Processed 100 videos, running average time/pair: 3.29 sec
#   Processed 110 videos, running average time/pair: 3.39 sec
#   Processed 120 videos, running average time/pair: 3.31 sec
#   Processed 130 videos, running average time/pair: 3.32 sec
#   Processed 140 videos, running average time/pair: 3.38 sec
#   Processed 150 videos, running average time/pair: 3.39 sec
#   Total process time: 9.17 min
# Preprocessing epoch block 209:
#   Processed 10 videos, running average time/pair: 3.52 sec
#   Processed 20 videos, running average time/pair: 3.65 sec
#   Processed 30 videos, running average time/pair: 3.62 sec
#   Processed 40 videos, running average time/pair: 3.54 sec
#   Processed 50 videos, running average time/pair: 3.14 sec
#   Processed 60 videos, running average time/pair: 3.50 sec
#   Processed 70 videos, running average time/pair: 3.48 sec
#   Processed 80 videos, running average time/pair: 3.01 sec
#   Processed 90 videos, running average time/pair: 3.38 sec
#   Processed 100 videos, running average time/pair: 3.26 sec
#   Processed 110 videos, running average time/pair: 3.41 sec
#   Processed 120 videos, running average time/pair: 3.84 sec
#   Processed 130 videos, running average time/pair: 3.53 sec
#   Processed 140 videos, running average time/pair: 3.60 sec
#   Processed 150 videos, running average time/pair: 3.46 sec
#   Processed 160 videos, running average time/pair: 3.07 sec
#   Total process time: 9.47 min
# Preprocessing epoch block 279:
#   Processed 10 videos, running average time/pair: 3.35 sec
#   Processed 20 videos, running average time/pair: 3.49 sec
#   Processed 30 videos, running average time/pair: 3.41 sec
#   Processed 40 videos, running average time/pair: 3.47 sec
#   Processed 50 videos, running average time/pair: 3.54 sec
#   Processed 60 videos, running average time/pair: 3.43 sec
#   Processed 70 videos, running average time/pair: 3.73 sec
#   Processed 80 videos, running average time/pair: 3.34 sec
#   Processed 90 videos, running average time/pair: 3.08 sec
#   Processed 100 videos, running average time/pair: 3.14 sec
#   Processed 110 videos, running average time/pair: 3.64 sec
#   Processed 120 videos, running average time/pair: 3.81 sec
#   Processed 130 videos, running average time/pair: 3.22 sec
#   Processed 140 videos, running average time/pair: 3.61 sec
#   Processed 150 videos, running average time/pair: 3.30 sec
#   Processed 160 videos, running average time/pair: 3.40 sec
#   Processed 170 videos, running average time/pair: 3.24 sec
#   Total process time: 9.70 min
# Preprocessing epoch block 352:
#   Total process time: 0.00 min
# Preprocessing epoch block 17:
#   Processed 10 videos, running average time/pair: 3.73 sec
#   Processed 20 videos, running average time/pair: 3.05 sec
#   Processed 30 videos, running average time/pair: 3.73 sec
#   Processed 40 videos, running average time/pair: 3.58 sec
#   Processed 50 videos, running average time/pair: 3.57 sec
#   Processed 60 videos, running average time/pair: 3.41 sec
#   Processed 70 videos, running average time/pair: 3.14 sec
#   Processed 80 videos, running average time/pair: 3.42 sec
#   Processed 90 videos, running average time/pair: 3.44 sec
#   Processed 100 videos, running average time/pair: 3.40 sec
#   Processed 110 videos, running average time/pair: 3.22 sec
#   Processed 120 videos, running average time/pair: 3.10 sec
#   Processed 130 videos, running average time/pair: 3.22 sec
#   Processed 140 videos, running average time/pair: 3.43 sec
#   Processed 150 videos, running average time/pair: 3.24 sec
#   Processed 160 videos, running average time/pair: 3.45 sec
#   Total process time: 9.50 min
# Preprocessing epoch block 393:
#   Processed 10 videos, running average time/pair: 3.14 sec
#   Processed 20 videos, running average time/pair: 3.11 sec
#   Processed 30 videos, running average time/pair: 3.41 sec
#   Processed 40 videos, running average time/pair: 3.44 sec
#   Processed 50 videos, running average time/pair: 3.42 sec
#   Processed 60 videos, running average time/pair: 3.39 sec
#   Processed 70 videos, running average time/pair: 3.09 sec
#   Processed 80 videos, running average time/pair: 3.29 sec
#   Processed 90 videos, running average time/pair: 3.33 sec
#   Processed 100 videos, running average time/pair: 3.14 sec
#   Processed 110 videos, running average time/pair: 3.07 sec
#   Processed 120 videos, running average time/pair: 3.49 sec
#   Processed 130 videos, running average time/pair: 3.36 sec
#   Processed 140 videos, running average time/pair: 3.41 sec
#   Processed 150 videos, running average time/pair: 3.27 sec
#   Processed 160 videos, running average time/pair: 3.27 sec
#   Processed 170 videos, running average time/pair: 3.14 sec
#   Total process time: 9.52 min
# Preprocessing epoch block 108:
#   Processed 10 videos, running average time/pair: 3.44 sec
#   Processed 20 videos, running average time/pair: 3.25 sec
#   Processed 30 videos, running average time/pair: 3.35 sec
#   Processed 40 videos, running average time/pair: 3.22 sec
#   Processed 50 videos, running average time/pair: 3.74 sec
#   Processed 60 videos, running average time/pair: 3.39 sec
#   Processed 70 videos, running average time/pair: 3.07 sec
#   Processed 80 videos, running average time/pair: 3.18 sec
#   Processed 90 videos, running average time/pair: 3.33 sec
#   Processed 100 videos, running average time/pair: 3.10 sec
#   Processed 110 videos, running average time/pair: 3.54 sec
#   Processed 120 videos, running average time/pair: 3.75 sec
#   Processed 130 videos, running average time/pair: 3.33 sec
#   Processed 140 videos, running average time/pair: 3.30 sec
#   Processed 150 videos, running average time/pair: 3.40 sec
#   Processed 160 videos, running average time/pair: 3.49 sec
#   Total process time: 9.13 min
# Preprocessing epoch block 264:
#   Processed 10 videos, running average time/pair: 3.27 sec
#   Processed 20 videos, running average time/pair: 3.45 sec
#   Processed 30 videos, running average time/pair: 3.26 sec
#   Processed 40 videos, running average time/pair: 3.14 sec
#   Processed 50 videos, running average time/pair: 3.50 sec
#   Processed 60 videos, running average time/pair: 3.41 sec
#   Processed 70 videos, running average time/pair: 3.48 sec
#   Processed 80 videos, running average time/pair: 3.38 sec
#   Processed 90 videos, running average time/pair: 3.51 sec
#   Processed 100 videos, running average time/pair: 3.04 sec
#   Processed 110 videos, running average time/pair: 3.48 sec
#   Processed 120 videos, running average time/pair: 3.13 sec
#   Processed 130 videos, running average time/pair: 3.45 sec
#   Processed 140 videos, running average time/pair: 3.36 sec
#   Processed 150 videos, running average time/pair: 3.20 sec
#   Processed 160 videos, running average time/pair: 3.46 sec
#   Processed 170 videos, running average time/pair: 3.25 sec
#   Total process time: 9.52 min
# Preprocessing epoch block 45:
#   Total process time: 0.00 min
# Preprocessing epoch block 70:
#   Processed 10 videos, running average time/pair: 3.29 sec
#   Processed 20 videos, running average time/pair: 3.31 sec
#   Processed 30 videos, running average time/pair: 3.36 sec
#   Processed 40 videos, running average time/pair: 3.66 sec
#   Processed 50 videos, running average time/pair: 3.30 sec
#   Processed 60 videos, running average time/pair: 3.25 sec
#   Processed 70 videos, running average time/pair: 3.20 sec
#   Processed 80 videos, running average time/pair: 3.54 sec
#   Processed 90 videos, running average time/pair: 3.19 sec
#   Processed 100 videos, running average time/pair: 3.38 sec
#   Processed 110 videos, running average time/pair: 3.20 sec
#   Processed 120 videos, running average time/pair: 3.36 sec
#   Processed 130 videos, running average time/pair: 3.42 sec
#   Processed 140 videos, running average time/pair: 3.49 sec
#   Processed 150 videos, running average time/pair: 3.50 sec
#   Processed 160 videos, running average time/pair: 3.53 sec
#   Total process time: 9.22 min
# Preprocessing epoch block 555:
#   Processed 10 videos, running average time/pair: 3.37 sec
#   Processed 20 videos, running average time/pair: 3.36 sec
#   Processed 30 videos, running average time/pair: 3.53 sec
#   Processed 40 videos, running average time/pair: 3.25 sec
#   Processed 50 videos, running average time/pair: 3.38 sec
#   Processed 60 videos, running average time/pair: 3.15 sec
#   Processed 70 videos, running average time/pair: 3.16 sec
#   Processed 80 videos, running average time/pair: 3.47 sec
#   Processed 90 videos, running average time/pair: 3.12 sec
#   Processed 100 videos, running average time/pair: 3.51 sec
#   Processed 110 videos, running average time/pair: 3.50 sec
#   Processed 120 videos, running average time/pair: 3.52 sec
#   Processed 130 videos, running average time/pair: 3.24 sec
#   Processed 140 videos, running average time/pair: 3.30 sec
#   Processed 150 videos, running average time/pair: 3.15 sec
#   Processed 160 videos, running average time/pair: 3.12 sec
#   Processed 170 videos, running average time/pair: 3.21 sec
#   Total process time: 9.65 min
# Preprocessing epoch block 119:
#   Total process time: 0.00 min
# Preprocessing epoch block 563:
#   Processed 10 videos, running average time/pair: 3.28 sec
#   Processed 20 videos, running average time/pair: 3.26 sec
#   Processed 30 videos, running average time/pair: 3.17 sec
#   Processed 40 videos, running average time/pair: 3.47 sec
#   Processed 50 videos, running average time/pair: 3.09 sec
#   Processed 60 videos, running average time/pair: 3.18 sec
#   Processed 70 videos, running average time/pair: 3.00 sec
#   Processed 80 videos, running average time/pair: 3.75 sec
#   Processed 90 videos, running average time/pair: 3.32 sec
#   Processed 100 videos, running average time/pair: 3.18 sec
#   Processed 110 videos, running average time/pair: 3.33 sec
#   Processed 120 videos, running average time/pair: 3.42 sec
#   Processed 130 videos, running average time/pair: 3.13 sec
#   Processed 140 videos, running average time/pair: 3.28 sec
#   Processed 150 videos, running average time/pair: 3.01 sec
#   Processed 160 videos, running average time/pair: 3.02 sec
#   Total process time: 8.65 min
# Preprocessing epoch block 573:
#   Processed 10 videos, running average time/pair: 3.44 sec
#   Processed 20 videos, running average time/pair: 3.17 sec
#   Processed 30 videos, running average time/pair: 3.16 sec
#   Processed 40 videos, running average time/pair: 3.29 sec
#   Processed 50 videos, running average time/pair: 3.16 sec
#   Processed 60 videos, running average time/pair: 3.05 sec
#   Processed 70 videos, running average time/pair: 4.10 sec
#   Processed 80 videos, running average time/pair: 3.16 sec
#   Processed 90 videos, running average time/pair: 2.90 sec
#   Processed 100 videos, running average time/pair: 3.49 sec
#   Processed 110 videos, running average time/pair: 3.26 sec
#   Processed 120 videos, running average time/pair: 3.11 sec
#   Processed 130 videos, running average time/pair: 3.21 sec
#   Processed 140 videos, running average time/pair: 3.35 sec
#   Processed 150 videos, running average time/pair: 3.32 sec
#   Processed 160 videos, running average time/pair: 3.25 sec
#   Total process time: 9.24 min
# Preprocessing epoch block 284:
#   Processed 10 videos, running average time/pair: 3.49 sec
#   Processed 20 videos, running average time/pair: 3.05 sec
#   Processed 30 videos, running average time/pair: 3.14 sec
#   Processed 40 videos, running average time/pair: 3.30 sec
#   Processed 50 videos, running average time/pair: 3.14 sec
#   Processed 60 videos, running average time/pair: 3.25 sec
#   Processed 70 videos, running average time/pair: 3.62 sec
#   Processed 80 videos, running average time/pair: 3.54 sec
#   Processed 90 videos, running average time/pair: 3.35 sec
#   Processed 100 videos, running average time/pair: 3.43 sec
#   Processed 110 videos, running average time/pair: 3.33 sec
#   Processed 120 videos, running average time/pair: 2.95 sec
#   Processed 130 videos, running average time/pair: 3.38 sec
#   Processed 140 videos, running average time/pair: 3.10 sec
#   Processed 150 videos, running average time/pair: 3.12 sec
#   Processed 160 videos, running average time/pair: 3.01 sec
#   Total process time: 9.12 min
# Preprocessing epoch block 476:
#   Processed 10 videos, running average time/pair: 3.17 sec
#   Processed 20 videos, running average time/pair: 2.83 sec
#   Processed 30 videos, running average time/pair: 3.29 sec
#   Processed 40 videos, running average time/pair: 3.02 sec
#   Processed 50 videos, running average time/pair: 3.13 sec
#   Processed 60 videos, running average time/pair: 3.41 sec
#   Processed 70 videos, running average time/pair: 3.43 sec
#   Processed 80 videos, running average time/pair: 3.58 sec
#   Processed 90 videos, running average time/pair: 3.12 sec
#   Processed 100 videos, running average time/pair: 3.18 sec
#   Processed 110 videos, running average time/pair: 3.03 sec
#   Processed 120 videos, running average time/pair: 3.33 sec
#   Processed 130 videos, running average time/pair: 3.34 sec
#   Processed 140 videos, running average time/pair: 3.56 sec
#   Processed 150 videos, running average time/pair: 3.87 sec
#   Processed 160 videos, running average time/pair: 2.77 sec
#   Total process time: 9.12 min
# Preprocessing epoch block 169:
#   Processed 10 videos, running average time/pair: 3.23 sec
#   Processed 20 videos, running average time/pair: 3.12 sec
#   Processed 30 videos, running average time/pair: 3.28 sec
#   Processed 40 videos, running average time/pair: 3.48 sec
#   Processed 50 videos, running average time/pair: 3.17 sec
#   Processed 60 videos, running average time/pair: 3.32 sec
#   Processed 70 videos, running average time/pair: 3.30 sec
#   Processed 80 videos, running average time/pair: 3.11 sec
#   Processed 90 videos, running average time/pair: 3.28 sec
#   Processed 100 videos, running average time/pair: 3.23 sec
#   Processed 110 videos, running average time/pair: 3.07 sec
#   Processed 120 videos, running average time/pair: 3.39 sec
#   Processed 130 videos, running average time/pair: 3.24 sec
#   Processed 140 videos, running average time/pair: 3.10 sec
#   Processed 150 videos, running average time/pair: 3.40 sec
#   Processed 160 videos, running average time/pair: 3.38 sec
#   Processed 170 videos, running average time/pair: 3.11 sec
#   Total process time: 9.20 min
# Preprocessing epoch block 62:
#   Processed 10 videos, running average time/pair: 3.52 sec
#   Processed 20 videos, running average time/pair: 3.73 sec
#   Processed 30 videos, running average time/pair: 3.35 sec
#   Processed 40 videos, running average time/pair: 3.19 sec
#   Processed 50 videos, running average time/pair: 3.37 sec
#   Processed 60 videos, running average time/pair: 3.31 sec
#   Processed 70 videos, running average time/pair: 3.44 sec
#   Processed 80 videos, running average time/pair: 3.39 sec
#   Processed 90 videos, running average time/pair: 3.31 sec
#   Processed 100 videos, running average time/pair: 3.22 sec
#   Processed 110 videos, running average time/pair: 3.31 sec
#   Processed 120 videos, running average time/pair: 3.35 sec
#   Processed 130 videos, running average time/pair: 3.44 sec
#   Processed 140 videos, running average time/pair: 3.30 sec
#   Processed 150 videos, running average time/pair: 3.62 sec
#   Processed 160 videos, running average time/pair: 3.20 sec
#   Total process time: 9.10 min
# Preprocessing epoch block 251:
#   Total process time: 0.00 min
# Preprocessing epoch block 519:
#   Processed 10 videos, running average time/pair: 3.11 sec
#   Processed 20 videos, running average time/pair: 2.85 sec
#   Processed 30 videos, running average time/pair: 2.98 sec
#   Processed 40 videos, running average time/pair: 3.07 sec
#   Processed 50 videos, running average time/pair: 3.13 sec
#   Processed 60 videos, running average time/pair: 3.20 sec
#   Processed 70 videos, running average time/pair: 2.95 sec
#   Processed 80 videos, running average time/pair: 3.07 sec
#   Processed 90 videos, running average time/pair: 3.22 sec
#   Processed 100 videos, running average time/pair: 3.45 sec
#   Processed 110 videos, running average time/pair: 3.16 sec
#   Processed 120 videos, running average time/pair: 3.13 sec
#   Processed 130 videos, running average time/pair: 3.03 sec
#   Processed 140 videos, running average time/pair: 3.17 sec
#   Processed 150 videos, running average time/pair: 3.44 sec
#   Processed 160 videos, running average time/pair: 3.58 sec
#   Total process time: 8.69 min
# Preprocessing epoch block 556:
#   Processed 10 videos, running average time/pair: 3.18 sec
#   Processed 20 videos, running average time/pair: 3.37 sec
#   Processed 30 videos, running average time/pair: 3.37 sec
#   Processed 40 videos, running average time/pair: 3.01 sec
#   Processed 50 videos, running average time/pair: 3.38 sec
#   Processed 60 videos, running average time/pair: 3.21 sec
#   Processed 70 videos, running average time/pair: 3.33 sec
#   Processed 80 videos, running average time/pair: 3.15 sec
#   Processed 90 videos, running average time/pair: 3.08 sec
#   Processed 100 videos, running average time/pair: 3.00 sec
#   Processed 110 videos, running average time/pair: 3.15 sec
#   Processed 120 videos, running average time/pair: 2.82 sec
#   Processed 130 videos, running average time/pair: 3.16 sec
#   Processed 140 videos, running average time/pair: 3.47 sec
#   Processed 150 videos, running average time/pair: 3.21 sec
#   Processed 160 videos, running average time/pair: 3.16 sec
#   Total process time: 8.89 min
# Preprocessing epoch block 519:
#   Total process time: 0.00 min
# Preprocessing epoch block 256:
#   Processed 10 videos, running average time/pair: 3.25 sec
#   Processed 20 videos, running average time/pair: 3.27 sec
#   Processed 30 videos, running average time/pair: 3.64 sec
#   Processed 40 videos, running average time/pair: 3.17 sec
#   Processed 50 videos, running average time/pair: 3.20 sec
#   Processed 60 videos, running average time/pair: 3.10 sec
#   Processed 70 videos, running average time/pair: 3.31 sec
#   Processed 80 videos, running average time/pair: 3.49 sec
#   Processed 90 videos, running average time/pair: 3.20 sec
#   Processed 100 videos, running average time/pair: 3.44 sec
#   Processed 110 videos, running average time/pair: 3.21 sec
#   Processed 120 videos, running average time/pair: 2.86 sec
#   Processed 130 videos, running average time/pair: 3.23 sec
#   Processed 140 videos, running average time/pair: 3.36 sec
#   Processed 150 videos, running average time/pair: 3.25 sec
#   Processed 160 videos, running average time/pair: 2.93 sec
#   Total process time: 9.08 min
# Preprocessing epoch block 494:
#   Processed 10 videos, running average time/pair: 3.11 sec
#   Processed 20 videos, running average time/pair: 3.01 sec
#   Processed 30 videos, running average time/pair: 3.17 sec
#   Processed 40 videos, running average time/pair: 2.99 sec
#   Processed 50 videos, running average time/pair: 3.18 sec
#   Processed 60 videos, running average time/pair: 3.01 sec
#   Processed 70 videos, running average time/pair: 3.10 sec
#   Processed 80 videos, running average time/pair: 2.90 sec
#   Processed 90 videos, running average time/pair: 3.12 sec
#   Processed 100 videos, running average time/pair: 3.56 sec
#   Processed 110 videos, running average time/pair: 3.24 sec
#   Processed 120 videos, running average time/pair: 3.37 sec
#   Processed 130 videos, running average time/pair: 3.28 sec
#   Processed 140 videos, running average time/pair: 3.01 sec
#   Processed 150 videos, running average time/pair: 3.18 sec
#   Processed 160 videos, running average time/pair: 3.55 sec
#   Processed 170 videos, running average time/pair: 3.23 sec
#   Total process time: 9.16 min
# Preprocessing epoch block 571:
#   Processed 10 videos, running average time/pair: 3.04 sec
#   Processed 20 videos, running average time/pair: 3.34 sec
#   Processed 30 videos, running average time/pair: 3.15 sec
#   Processed 40 videos, running average time/pair: 3.29 sec
#   Processed 50 videos, running average time/pair: 3.32 sec
#   Processed 60 videos, running average time/pair: 2.89 sec
#   Processed 70 videos, running average time/pair: 3.27 sec
#   Processed 80 videos, running average time/pair: 3.53 sec
#   Processed 90 videos, running average time/pair: 3.58 sec
#   Processed 100 videos, running average time/pair: 3.08 sec
#   Processed 110 videos, running average time/pair: 2.98 sec
#   Processed 120 videos, running average time/pair: 3.19 sec
#   Processed 130 videos, running average time/pair: 3.46 sec
#   Processed 140 videos, running average time/pair: 3.26 sec
#   Processed 150 videos, running average time/pair: 3.55 sec
#   Processed 160 videos, running average time/pair: 3.16 sec
#   Total process time: 8.79 min
# Preprocessing epoch block 420:
#   Processed 10 videos, running average time/pair: 3.30 sec
#   Processed 20 videos, running average time/pair: 3.05 sec
#   Processed 30 videos, running average time/pair: 3.85 sec
#   Processed 40 videos, running average time/pair: 3.09 sec
#   Processed 50 videos, running average time/pair: 3.07 sec
#   Processed 60 videos, running average time/pair: 3.22 sec
#   Processed 70 videos, running average time/pair: 3.46 sec
#   Processed 80 videos, running average time/pair: 3.00 sec
#   Processed 90 videos, running average time/pair: 3.13 sec
#   Processed 100 videos, running average time/pair: 3.38 sec
#   Processed 110 videos, running average time/pair: 2.96 sec
#   Processed 120 videos, running average time/pair: 3.24 sec
#   Processed 130 videos, running average time/pair: 3.23 sec
#   Processed 140 videos, running average time/pair: 3.08 sec
#   Processed 150 videos, running average time/pair: 3.41 sec
#   Processed 160 videos, running average time/pair: 3.20 sec
#   Total process time: 8.97 min
# Preprocessing epoch block 214:
#   Processed 10 videos, running average time/pair: 3.18 sec
#   Processed 20 videos, running average time/pair: 3.21 sec
#   Processed 30 videos, running average time/pair: 3.51 sec
#   Processed 40 videos, running average time/pair: 3.23 sec
#   Processed 50 videos, running average time/pair: 3.01 sec
#   Processed 60 videos, running average time/pair: 2.97 sec
#   Processed 70 videos, running average time/pair: 3.13 sec
#   Processed 80 videos, running average time/pair: 3.22 sec
#   Processed 90 videos, running average time/pair: 2.87 sec
#   Processed 100 videos, running average time/pair: 3.14 sec
#   Processed 110 videos, running average time/pair: 3.45 sec
#   Processed 120 videos, running average time/pair: 3.09 sec
#   Processed 130 videos, running average time/pair: 3.16 sec
#   Processed 140 videos, running average time/pair: 3.36 sec
#   Processed 150 videos, running average time/pair: 3.00 sec
#   Processed 160 videos, running average time/pair: 3.06 sec
#   Total process time: 8.83 min
# Preprocessing epoch block 550:
#   Total process time: 0.00 min
# Preprocessing epoch block 388:
#   Processed 10 videos, running average time/pair: 2.89 sec
#   Processed 20 videos, running average time/pair: 3.21 sec
#   Processed 30 videos, running average time/pair: 3.02 sec
#   Processed 40 videos, running average time/pair: 3.05 sec
#   Processed 50 videos, running average time/pair: 2.94 sec
#   Processed 60 videos, running average time/pair: 3.21 sec
#   Processed 70 videos, running average time/pair: 2.95 sec
#   Processed 80 videos, running average time/pair: 3.17 sec
#   Processed 90 videos, running average time/pair: 3.06 sec
#   Processed 100 videos, running average time/pair: 3.09 sec
#   Processed 110 videos, running average time/pair: 3.10 sec
#   Processed 120 videos, running average time/pair: 3.26 sec
#   Processed 130 videos, running average time/pair: 3.35 sec
#   Processed 140 videos, running average time/pair: 3.21 sec
#   Processed 150 videos, running average time/pair: 3.07 sec
#   Processed 160 videos, running average time/pair: 2.98 sec
#   Total process time: 8.61 min
# Preprocessing epoch block 553:
#   Processed 10 videos, running average time/pair: 3.17 sec
#   Processed 20 videos, running average time/pair: 3.24 sec
#   Processed 30 videos, running average time/pair: 3.13 sec
#   Processed 40 videos, running average time/pair: 3.00 sec
#   Processed 50 videos, running average time/pair: 3.12 sec
#   Processed 60 videos, running average time/pair: 3.47 sec
#   Processed 70 videos, running average time/pair: 3.21 sec
#   Processed 80 videos, running average time/pair: 3.06 sec
#   Processed 90 videos, running average time/pair: 3.22 sec
#   Processed 100 videos, running average time/pair: 3.18 sec
#   Processed 110 videos, running average time/pair: 3.20 sec
#   Processed 120 videos, running average time/pair: 3.20 sec
#   Processed 130 videos, running average time/pair: 3.06 sec
#   Processed 140 videos, running average time/pair: 3.28 sec
#   Processed 150 videos, running average time/pair: 3.48 sec
#   Processed 160 videos, running average time/pair: 3.03 sec
#   Processed 170 videos, running average time/pair: 3.51 sec
#   Total process time: 9.16 min
# Preprocessing epoch block 577:
#   Processed 10 videos, running average time/pair: 3.05 sec
#   Processed 20 videos, running average time/pair: 3.22 sec
#   Processed 30 videos, running average time/pair: 3.34 sec
#   Processed 40 videos, running average time/pair: 2.97 sec
#   Processed 50 videos, running average time/pair: 2.85 sec
#   Processed 60 videos, running average time/pair: 3.37 sec
#   Processed 70 videos, running average time/pair: 3.14 sec
#   Processed 80 videos, running average time/pair: 3.50 sec
#   Processed 90 videos, running average time/pair: 3.12 sec
#   Processed 100 videos, running average time/pair: 3.01 sec
#   Processed 110 videos, running average time/pair: 3.13 sec
#   Processed 120 videos, running average time/pair: 3.38 sec
#   Processed 130 videos, running average time/pair: 3.05 sec
#   Processed 140 videos, running average time/pair: 3.05 sec
#   Processed 150 videos, running average time/pair: 3.07 sec
#   Total process time: 8.15 min
# Preprocessing epoch block 65:
#   Processed 10 videos, running average time/pair: 3.00 sec
#   Processed 20 videos, running average time/pair: 3.03 sec
#   Processed 30 videos, running average time/pair: 3.18 sec
#   Processed 40 videos, running average time/pair: 2.98 sec
#   Processed 50 videos, running average time/pair: 3.10 sec
#   Processed 60 videos, running average time/pair: 3.33 sec
#   Processed 70 videos, running average time/pair: 3.03 sec
#   Processed 80 videos, running average time/pair: 3.04 sec
#   Processed 90 videos, running average time/pair: 3.11 sec
#   Processed 100 videos, running average time/pair: 3.48 sec
#   Processed 110 videos, running average time/pair: 3.06 sec
#   Processed 120 videos, running average time/pair: 3.13 sec
#   Processed 130 videos, running average time/pair: 2.93 sec
#   Processed 140 videos, running average time/pair: 3.26 sec
#   Processed 150 videos, running average time/pair: 2.98 sec
#   Processed 160 videos, running average time/pair: 3.23 sec
#   Total process time: 8.79 min
# Preprocessing epoch block 373:
#   Processed 10 videos, running average time/pair: 3.13 sec
#   Processed 20 videos, running average time/pair: 3.28 sec
#   Processed 30 videos, running average time/pair: 3.14 sec
#   Processed 40 videos, running average time/pair: 3.03 sec
#   Processed 50 videos, running average time/pair: 3.40 sec
#   Processed 60 videos, running average time/pair: 2.60 sec
#   Processed 70 videos, running average time/pair: 3.15 sec
#   Processed 80 videos, running average time/pair: 3.34 sec
#   Processed 90 videos, running average time/pair: 3.09 sec
#   Processed 100 videos, running average time/pair: 3.04 sec
#   Processed 110 videos, running average time/pair: 3.01 sec
#   Processed 120 videos, running average time/pair: 3.14 sec
#   Processed 130 videos, running average time/pair: 2.69 sec
#   Processed 140 videos, running average time/pair: 3.24 sec
#   Processed 150 videos, running average time/pair: 3.37 sec
#   Processed 160 videos, running average time/pair: 3.22 sec
#   Processed 170 videos, running average time/pair: 3.08 sec
#   Total process time: 8.83 min
# Preprocessing epoch block 394:
#   Processed 10 videos, running average time/pair: 3.26 sec
#   Processed 20 videos, running average time/pair: 3.15 sec
#   Processed 30 videos, running average time/pair: 3.09 sec
#   Processed 40 videos, running average time/pair: 3.34 sec
#   Processed 50 videos, running average time/pair: 3.04 sec
#   Processed 60 videos, running average time/pair: 3.15 sec
#   Processed 70 videos, running average time/pair: 2.85 sec
#   Processed 80 videos, running average time/pair: 3.57 sec
#   Processed 90 videos, running average time/pair: 3.27 sec
#   Processed 100 videos, running average time/pair: 3.48 sec
#   Processed 110 videos, running average time/pair: 3.43 sec
#   Processed 120 videos, running average time/pair: 2.97 sec
#   Processed 130 videos, running average time/pair: 3.14 sec
#   Processed 140 videos, running average time/pair: 3.11 sec
#   Processed 150 videos, running average time/pair: 3.35 sec
#   Processed 160 videos, running average time/pair: 3.25 sec
#   Processed 170 videos, running average time/pair: 3.43 sec
#   Total process time: 9.35 min
# Preprocessing epoch block 276:
#   Processed 10 videos, running average time/pair: 3.28 sec
#   Processed 20 videos, running average time/pair: 3.25 sec
#   Processed 30 videos, running average time/pair: 3.14 sec
#   Processed 40 videos, running average time/pair: 3.38 sec
#   Processed 50 videos, running average time/pair: 3.24 sec
#   Processed 60 videos, running average time/pair: 3.35 sec
#   Processed 70 videos, running average time/pair: 3.30 sec
#   Processed 80 videos, running average time/pair: 2.91 sec
#   Processed 90 videos, running average time/pair: 3.15 sec
#   Processed 100 videos, running average time/pair: 2.90 sec
#   Processed 110 videos, running average time/pair: 3.15 sec
#   Processed 120 videos, running average time/pair: 3.32 sec
#   Processed 130 videos, running average time/pair: 2.89 sec
#   Processed 140 videos, running average time/pair: 2.96 sec
#   Processed 150 videos, running average time/pair: 2.84 sec
#   Processed 160 videos, running average time/pair: 2.98 sec
#   Total process time: 8.69 min
# Preprocessing epoch block 254:
#   Processed 10 videos, running average time/pair: 2.67 sec
#   Processed 20 videos, running average time/pair: 3.09 sec
#   Processed 30 videos, running average time/pair: 2.95 sec
#   Processed 40 videos, running average time/pair: 3.08 sec
#   Processed 50 videos, running average time/pair: 3.02 sec
#   Processed 60 videos, running average time/pair: 2.80 sec
#   Processed 70 videos, running average time/pair: 3.13 sec
#   Processed 80 videos, running average time/pair: 3.94 sec
#   Processed 90 videos, running average time/pair: 3.06 sec
#   Processed 100 videos, running average time/pair: 3.02 sec
#   Processed 110 videos, running average time/pair: 3.00 sec
#   Processed 120 videos, running average time/pair: 3.12 sec
#   Processed 130 videos, running average time/pair: 3.07 sec
#   Processed 140 videos, running average time/pair: 3.16 sec
#   Processed 150 videos, running average time/pair: 3.12 sec
#   Processed 160 videos, running average time/pair: 3.17 sec
#   Processed 170 videos, running average time/pair: 2.83 sec
#   Total process time: 9.12 min
# Preprocessing epoch block 255:
#   Processed 10 videos, running average time/pair: 3.25 sec
#   Processed 20 videos, running average time/pair: 3.00 sec
#   Processed 30 videos, running average time/pair: 2.95 sec
#   Processed 40 videos, running average time/pair: 3.14 sec
#   Processed 50 videos, running average time/pair: 2.88 sec
#   Processed 60 videos, running average time/pair: 3.10 sec
#   Processed 70 videos, running average time/pair: 2.76 sec
#   Processed 80 videos, running average time/pair: 2.90 sec
#   Processed 90 videos, running average time/pair: 3.15 sec
#   Processed 100 videos, running average time/pair: 3.12 sec
#   Processed 110 videos, running average time/pair: 3.09 sec
#   Processed 120 videos, running average time/pair: 2.90 sec
#   Processed 130 videos, running average time/pair: 2.91 sec
#   Processed 140 videos, running average time/pair: 3.19 sec
#   Processed 150 videos, running average time/pair: 3.09 sec
#   Processed 160 videos, running average time/pair: 2.84 sec
#   Total process time: 8.48 min
# Preprocessing epoch block 47:
#   Processed 10 videos, running average time/pair: 3.11 sec
#   Processed 20 videos, running average time/pair: 3.10 sec
#   Processed 30 videos, running average time/pair: 3.05 sec
#   Processed 40 videos, running average time/pair: 3.07 sec
#   Processed 50 videos, running average time/pair: 2.58 sec
#   Processed 60 videos, running average time/pair: 3.10 sec
#   Processed 70 videos, running average time/pair: 3.14 sec
#   Processed 80 videos, running average time/pair: 3.13 sec
#   Processed 90 videos, running average time/pair: 2.78 sec
#   Processed 100 videos, running average time/pair: 3.43 sec
#   Processed 110 videos, running average time/pair: 2.74 sec
#   Processed 120 videos, running average time/pair: 3.00 sec
#   Processed 130 videos, running average time/pair: 2.47 sec
#   Processed 140 videos, running average time/pair: 3.11 sec
#   Processed 150 videos, running average time/pair: 3.10 sec
#   Processed 160 videos, running average time/pair: 2.95 sec
#   Total process time: 8.38 min
# Preprocessing epoch block 415:
#   Processed 10 videos, running average time/pair: 3.04 sec
#   Processed 20 videos, running average time/pair: 2.98 sec
#   Processed 30 videos, running average time/pair: 3.16 sec
#   Processed 40 videos, running average time/pair: 2.82 sec
#   Processed 50 videos, running average time/pair: 3.03 sec
#   Processed 60 videos, running average time/pair: 3.04 sec
#   Processed 70 videos, running average time/pair: 3.05 sec
#   Processed 80 videos, running average time/pair: 3.40 sec
#   Processed 90 videos, running average time/pair: 2.96 sec
#   Processed 100 videos, running average time/pair: 2.99 sec
#   Processed 110 videos, running average time/pair: 2.96 sec
#   Processed 120 videos, running average time/pair: 3.16 sec
#   Processed 130 videos, running average time/pair: 2.91 sec
#   Processed 140 videos, running average time/pair: 3.11 sec
#   Processed 150 videos, running average time/pair: 2.96 sec
#   Processed 160 videos, running average time/pair: 3.22 sec
#   Total process time: 8.49 min
# Preprocessing epoch block 203:
#   Processed 10 videos, running average time/pair: 2.84 sec
#   Processed 20 videos, running average time/pair: 2.99 sec
#   Processed 30 videos, running average time/pair: 2.50 sec
#   Processed 40 videos, running average time/pair: 2.96 sec
#   Processed 50 videos, running average time/pair: 3.01 sec
#   Processed 60 videos, running average time/pair: 3.07 sec
#   Processed 70 videos, running average time/pair: 3.03 sec
#   Processed 80 videos, running average time/pair: 2.93 sec
#   Processed 90 videos, running average time/pair: 2.90 sec
#   Processed 100 videos, running average time/pair: 3.00 sec
#   Processed 110 videos, running average time/pair: 3.12 sec
#   Processed 120 videos, running average time/pair: 3.07 sec
#   Processed 130 videos, running average time/pair: 2.93 sec
#   Processed 140 videos, running average time/pair: 3.18 sec
#   Processed 150 videos, running average time/pair: 2.91 sec
#   Processed 160 videos, running average time/pair: 2.90 sec
#   Total process time: 8.30 min
# Preprocessing epoch block 311:
#   Processed 10 videos, running average time/pair: 2.92 sec
#   Processed 20 videos, running average time/pair: 2.87 sec
#   Processed 30 videos, running average time/pair: 2.82 sec
#   Processed 40 videos, running average time/pair: 3.00 sec
#   Processed 50 videos, running average time/pair: 3.05 sec
#   Processed 60 videos, running average time/pair: 3.23 sec
#   Processed 70 videos, running average time/pair: 3.01 sec
#   Processed 80 videos, running average time/pair: 2.85 sec
#   Processed 90 videos, running average time/pair: 2.78 sec
#   Processed 100 videos, running average time/pair: 3.13 sec
#   Processed 110 videos, running average time/pair: 3.22 sec
#   Processed 120 videos, running average time/pair: 3.02 sec
#   Processed 130 videos, running average time/pair: 3.07 sec
#   Processed 140 videos, running average time/pair: 3.99 sec
#   Processed 150 videos, running average time/pair: 2.95 sec
#   Processed 160 videos, running average time/pair: 2.95 sec
#   Processed 170 videos, running average time/pair: 2.92 sec
#   Total process time: 8.63 min
# Preprocessing epoch block 188:
#   Processed 10 videos, running average time/pair: 3.21 sec
#   Processed 20 videos, running average time/pair: 2.87 sec
#   Processed 30 videos, running average time/pair: 3.13 sec
#   Processed 40 videos, running average time/pair: 3.12 sec
#   Processed 50 videos, running average time/pair: 3.33 sec
#   Processed 60 videos, running average time/pair: 3.25 sec
#   Processed 70 videos, running average time/pair: 3.08 sec
#   Processed 80 videos, running average time/pair: 2.93 sec
#   Processed 90 videos, running average time/pair: 3.19 sec
#   Processed 100 videos, running average time/pair: 2.87 sec
#   Processed 110 videos, running average time/pair: 2.96 sec
#   Processed 120 videos, running average time/pair: 2.83 sec
#   Processed 130 videos, running average time/pair: 2.97 sec
#   Processed 140 videos, running average time/pair: 3.27 sec
#   Processed 150 videos, running average time/pair: 2.91 sec
#   Processed 160 videos, running average time/pair: 2.92 sec
#   Processed 170 videos, running average time/pair: 2.93 sec
#   Total process time: 8.63 min
# Preprocessing epoch block 263:
#   Processed 10 videos, running average time/pair: 2.78 sec
#   Processed 20 videos, running average time/pair: 2.99 sec
#   Processed 30 videos, running average time/pair: 3.01 sec
#   Processed 40 videos, running average time/pair: 2.91 sec
#   Processed 50 videos, running average time/pair: 2.99 sec
#   Processed 60 videos, running average time/pair: 3.05 sec
#   Processed 70 videos, running average time/pair: 3.03 sec
#   Processed 80 videos, running average time/pair: 3.25 sec
#   Processed 90 videos, running average time/pair: 3.22 sec
#   Processed 100 videos, running average time/pair: 2.94 sec
#   Processed 110 videos, running average time/pair: 2.98 sec
#   Processed 120 videos, running average time/pair: 3.10 sec
#   Processed 130 videos, running average time/pair: 2.83 sec
#   Processed 140 videos, running average time/pair: 3.17 sec
#   Processed 150 videos, running average time/pair: 2.99 sec
#   Processed 160 videos, running average time/pair: 2.97 sec
#   Processed 170 videos, running average time/pair: 2.96 sec
#   Total process time: 8.71 min
# Preprocessing epoch block 544:
#   Processed 10 videos, running average time/pair: 3.17 sec
#   Processed 20 videos, running average time/pair: 2.99 sec
#   Processed 30 videos, running average time/pair: 3.36 sec
#   Processed 40 videos, running average time/pair: 2.82 sec
#   Processed 50 videos, running average time/pair: 3.07 sec
#   Processed 60 videos, running average time/pair: 3.04 sec
#   Processed 70 videos, running average time/pair: 2.94 sec
#   Processed 80 videos, running average time/pair: 3.03 sec
#   Processed 90 videos, running average time/pair: 3.12 sec
#   Processed 100 videos, running average time/pair: 3.08 sec
#   Processed 110 videos, running average time/pair: 2.99 sec
#   Processed 120 videos, running average time/pair: 2.92 sec
#   Processed 130 videos, running average time/pair: 3.04 sec
#   Processed 140 videos, running average time/pair: 2.95 sec
#   Processed 150 videos, running average time/pair: 2.66 sec
#   Processed 160 videos, running average time/pair: 3.10 sec
#   Processed 170 videos, running average time/pair: 2.93 sec
#   Total process time: 8.62 min
# Preprocessing epoch block 198:
#   Processed 10 videos, running average time/pair: 3.00 sec
#   Processed 20 videos, running average time/pair: 2.61 sec
#   Processed 30 videos, running average time/pair: 3.06 sec
#   Processed 40 videos, running average time/pair: 2.84 sec
#   Processed 50 videos, running average time/pair: 2.99 sec
#   Processed 60 videos, running average time/pair: 3.19 sec
#   Processed 70 videos, running average time/pair: 2.82 sec
#   Processed 80 videos, running average time/pair: 2.86 sec
#   Processed 90 videos, running average time/pair: 2.98 sec
#   Processed 100 videos, running average time/pair: 2.85 sec
#   Processed 110 videos, running average time/pair: 2.87 sec
#   Processed 120 videos, running average time/pair: 2.76 sec
#   Processed 130 videos, running average time/pair: 2.99 sec
#   Processed 140 videos, running average time/pair: 3.20 sec
#   Processed 150 videos, running average time/pair: 3.14 sec
#   Total process time: 7.79 min
# Preprocessing epoch block 299:
#   Processed 10 videos, running average time/pair: 2.86 sec
#   Processed 20 videos, running average time/pair: 2.86 sec
#   Processed 30 videos, running average time/pair: 3.08 sec
#   Processed 40 videos, running average time/pair: 2.82 sec
#   Processed 50 videos, running average time/pair: 2.98 sec
#   Processed 60 videos, running average time/pair: 2.74 sec
#   Processed 70 videos, running average time/pair: 3.01 sec
#   Processed 80 videos, running average time/pair: 2.96 sec
#   Processed 90 videos, running average time/pair: 2.99 sec
#   Processed 100 videos, running average time/pair: 2.89 sec
#   Processed 110 videos, running average time/pair: 2.84 sec
#   Processed 120 videos, running average time/pair: 2.87 sec
#   Processed 130 videos, running average time/pair: 2.98 sec
#   Processed 140 videos, running average time/pair: 3.03 sec
#   Processed 150 videos, running average time/pair: 3.13 sec
#   Total process time: 7.65 min
# Preprocessing epoch block 342:
#   Processed 10 videos, running average time/pair: 3.30 sec
#   Processed 20 videos, running average time/pair: 3.10 sec
#   Processed 30 videos, running average time/pair: 2.93 sec
#   Processed 40 videos, running average time/pair: 3.17 sec
#   Processed 50 videos, running average time/pair: 3.08 sec
#   Processed 60 videos, running average time/pair: 3.13 sec
#   Processed 70 videos, running average time/pair: 3.04 sec
#   Processed 80 videos, running average time/pair: 3.01 sec
#   Processed 90 videos, running average time/pair: 2.99 sec
#   Processed 100 videos, running average time/pair: 2.92 sec
#   Processed 110 videos, running average time/pair: 2.90 sec
#   Processed 120 videos, running average time/pair: 2.89 sec
#   Processed 130 videos, running average time/pair: 3.40 sec
#   Processed 140 videos, running average time/pair: 2.81 sec
#   Processed 150 videos, running average time/pair: 3.51 sec
#   Processed 160 videos, running average time/pair: 3.18 sec
#   Total process time: 8.33 min
# Preprocessing epoch block 9:
#   Processed 10 videos, running average time/pair: 3.23 sec
#   Processed 20 videos, running average time/pair: 3.17 sec
#   Processed 30 videos, running average time/pair: 2.99 sec
#   Processed 40 videos, running average time/pair: 2.87 sec
#   Processed 50 videos, running average time/pair: 2.89 sec
#   Processed 60 videos, running average time/pair: 3.25 sec
#   Processed 70 videos, running average time/pair: 2.88 sec
#   Processed 80 videos, running average time/pair: 3.30 sec
#   Processed 90 videos, running average time/pair: 3.16 sec
#   Processed 100 videos, running average time/pair: 2.77 sec
#   Processed 110 videos, running average time/pair: 2.90 sec
#   Processed 120 videos, running average time/pair: 3.05 sec
#   Processed 130 videos, running average time/pair: 2.77 sec
#   Processed 140 videos, running average time/pair: 3.17 sec
#   Processed 150 videos, running average time/pair: 3.25 sec
#   Processed 160 videos, running average time/pair: 2.87 sec
#   Total process time: 8.44 min
# Preprocessing epoch block 402:
#   Processed 10 videos, running average time/pair: 2.96 sec
#   Processed 20 videos, running average time/pair: 3.12 sec
#   Processed 30 videos, running average time/pair: 2.83 sec
#   Processed 40 videos, running average time/pair: 2.80 sec
#   Processed 50 videos, running average time/pair: 3.03 sec
#   Processed 60 videos, running average time/pair: 3.11 sec
#   Processed 70 videos, running average time/pair: 2.79 sec
#   Processed 80 videos, running average time/pair: 3.09 sec
#   Processed 90 videos, running average time/pair: 3.02 sec
#   Processed 100 videos, running average time/pair: 3.02 sec
#   Processed 110 videos, running average time/pair: 3.24 sec
#   Processed 120 videos, running average time/pair: 2.80 sec
#   Processed 130 videos, running average time/pair: 2.99 sec
#   Processed 140 videos, running average time/pair: 2.92 sec
#   Processed 150 videos, running average time/pair: 3.17 sec
#   Processed 160 videos, running average time/pair: 2.88 sec
#   Processed 170 videos, running average time/pair: 2.93 sec
#   Total process time: 8.50 min
# Preprocessing epoch block 470:
#   Processed 10 videos, running average time/pair: 2.88 sec
#   Processed 20 videos, running average time/pair: 2.74 sec
#   Processed 30 videos, running average time/pair: 2.97 sec
#   Processed 40 videos, running average time/pair: 3.20 sec
#   Processed 50 videos, running average time/pair: 2.89 sec
#   Processed 60 videos, running average time/pair: 2.77 sec
#   Processed 70 videos, running average time/pair: 2.89 sec
#   Processed 80 videos, running average time/pair: 2.88 sec
#   Processed 90 videos, running average time/pair: 2.82 sec
#   Processed 100 videos, running average time/pair: 2.95 sec
#   Processed 110 videos, running average time/pair: 2.84 sec
#   Processed 120 videos, running average time/pair: 3.05 sec
#   Processed 130 videos, running average time/pair: 3.13 sec
#   Processed 140 videos, running average time/pair: 2.98 sec
#   Processed 150 videos, running average time/pair: 3.05 sec
#   Processed 160 videos, running average time/pair: 2.86 sec
#   Total process time: 8.03 min
# Preprocessing epoch block 352:
#   Total process time: 0.00 min
# Preprocessing epoch block 53:
#   Processed 10 videos, running average time/pair: 2.88 sec
#   Processed 20 videos, running average time/pair: 2.97 sec
#   Processed 30 videos, running average time/pair: 3.01 sec
#   Processed 40 videos, running average time/pair: 2.96 sec
#   Processed 50 videos, running average time/pair: 2.93 sec
#   Processed 60 videos, running average time/pair: 3.22 sec
#   Processed 70 videos, running average time/pair: 3.24 sec
#   Processed 80 videos, running average time/pair: 2.99 sec
#   Processed 90 videos, running average time/pair: 3.23 sec
#   Processed 100 videos, running average time/pair: 3.00 sec
#   Processed 110 videos, running average time/pair: 3.05 sec
#   Processed 120 videos, running average time/pair: 3.23 sec
#   Processed 130 videos, running average time/pair: 3.01 sec
#   Processed 140 videos, running average time/pair: 3.10 sec
#   Processed 150 videos, running average time/pair: 3.37 sec
#   Processed 160 videos, running average time/pair: 3.06 sec
#   Total process time: 8.66 min
# Preprocessing epoch block 115:
#   Processed 10 videos, running average time/pair: 2.98 sec
#   Processed 20 videos, running average time/pair: 2.92 sec
#   Processed 30 videos, running average time/pair: 3.11 sec
#   Processed 40 videos, running average time/pair: 3.05 sec
#   Processed 50 videos, running average time/pair: 2.93 sec
#   Processed 60 videos, running average time/pair: 3.33 sec
#   Processed 70 videos, running average time/pair: 2.91 sec
#   Processed 80 videos, running average time/pair: 2.69 sec
#   Processed 90 videos, running average time/pair: 2.70 sec
#   Processed 100 videos, running average time/pair: 2.96 sec
#   Processed 110 videos, running average time/pair: 3.08 sec
#   Processed 120 videos, running average time/pair: 3.21 sec
#   Processed 130 videos, running average time/pair: 2.83 sec
#   Processed 140 videos, running average time/pair: 3.00 sec
#   Processed 150 videos, running average time/pair: 2.80 sec
#   Processed 160 videos, running average time/pair: 2.83 sec
#   Total process time: 8.22 min
# Preprocessing epoch block 337:
#   Total process time: 0.00 min
# Preprocessing epoch block 319:
#   Processed 10 videos, running average time/pair: 2.99 sec
#   Processed 20 videos, running average time/pair: 3.25 sec
#   Processed 30 videos, running average time/pair: 3.10 sec
#   Processed 40 videos, running average time/pair: 2.98 sec
#   Processed 50 videos, running average time/pair: 3.06 sec
#   Processed 60 videos, running average time/pair: 2.99 sec
#   Processed 70 videos, running average time/pair: 2.83 sec
#   Processed 80 videos, running average time/pair: 2.72 sec
#   Processed 90 videos, running average time/pair: 2.50 sec
#   Processed 100 videos, running average time/pair: 3.03 sec
#   Processed 110 videos, running average time/pair: 3.11 sec
#   Processed 120 videos, running average time/pair: 2.95 sec
#   Processed 130 videos, running average time/pair: 3.11 sec
#   Processed 140 videos, running average time/pair: 2.89 sec
#   Processed 150 videos, running average time/pair: 3.09 sec
#   Processed 160 videos, running average time/pair: 2.90 sec
#   Total process time: 8.12 min
# Preprocessing epoch block 341:
#   Processed 10 videos, running average time/pair: 2.79 sec
#   Processed 20 videos, running average time/pair: 2.84 sec
#   Processed 30 videos, running average time/pair: 3.08 sec
#   Processed 40 videos, running average time/pair: 2.89 sec
#   Processed 50 videos, running average time/pair: 3.14 sec
#   Processed 60 videos, running average time/pair: 3.05 sec
#   Processed 70 videos, running average time/pair: 3.01 sec
#   Processed 80 videos, running average time/pair: 2.91 sec
#   Processed 90 videos, running average time/pair: 3.12 sec
#   Processed 100 videos, running average time/pair: 2.81 sec
#   Processed 110 videos, running average time/pair: 2.95 sec
#   Processed 120 videos, running average time/pair: 3.03 sec
#   Processed 130 videos, running average time/pair: 2.81 sec
#   Processed 140 videos, running average time/pair: 2.83 sec
#   Processed 150 videos, running average time/pair: 2.99 sec
#   Processed 160 videos, running average time/pair: 3.38 sec
#   Total process time: 7.99 min
# Preprocessing epoch block 173:
#   Total process time: 0.00 min
# Preprocessing epoch block 98:
#   Total process time: 0.00 min
# Preprocessing epoch block 116:
#   Processed 10 videos, running average time/pair: 2.93 sec

# %%
# This fcn takes just an initial glance at the video and metadata
# in the training set and prints out some informational metrics.
def summarize_data(istart, istop=None, netsum=True, verbose=False):
#{
    # Like range args
    if istop is None:
        istart, istop = 0, istart

    summation = []
    for i in range(istart, istop):
    #{
        try:
        #{
            numvids, numtrain, vidsfounds, numfakes, origfound = 0,0,0,0,0
            with open(f"{df.traindir(i)}/metadata.json") as jsonfile:
            #{
                metadata = json.load(jsonfile)
                for vidname, meta in metadata.items():
                #{
                    vname = f"{df.traindir(i)}/{vidname}"
                    numvids += 1

                    if meta['split'] == 'train': numtrain += 1
                    if df.file_exists(vname): vidsfounds += 1

                    if (meta['label'] == 'FAKE'):
                        oname = f"{df.traindir(i)}/{meta['original']}"
                        if df.file_exists(oname): origfound += 1
                        numfakes += 1
                #}
            #}
        #}
        except PermissionError as err: print("ERROR:", err)
        
        if verbose:
            print(f"Partition: {df.trainpart(i)}:")
            print(f"  Numb of primary video meta-references/train split: {numvids}/{numtrain}")
            print(f"  Numb of actual primary videos files found on disk: {vidsfounds}")
            print(f"  Numb of fake/original meta-pairs: {numfakes}")
            print(f"  Numb of actual video pairs found on disk: {origfound}")
            
        if (numvids != vidsfounds) or (numvids != numtrain) or (numfakes != origfound):
            print(f"  DISCREPENCY found in partition {df.trainpart(i)}")
            
        if netsum: summation.append((numvids, numtrain, vidsfounds, numfakes, origfound))
    #}
    
    if netsum:
    #{
        numvids, numtrain, vidsfounds, numfakes, origfound = functools.reduce(
            lambda st1, st2: (st1[0]+st2[0], st1[1]+st2[1], st1[2]+st2[2], 
                              st1[3]+st2[3], st1[4]+st2[4]), summation)
        
        print(f"\nNet dataset summary:")
        print(f"  Numb of primary video meta-references/train split: {numvids}/{numtrain}")
        print(f"  Numb of actual primary videos files found on disk: {vidsfounds}")
        print(f"  Numb of fake/original meta-pairs: {numfakes}")
        print(f"  Numb of actual video pairs found on disk: {origfound}\n")
    #}
#}

if dfc.DATA_SOURCE == 'production':
#{
    summarize_data(50, verbose=False)

    # Partitions 18 and 35 appear slightly incomplete.
    # summarize_data(18, 19, netsum=False, verbose=True)
    # summarize_data(35, 36, netsum=False, verbose=True)
#}
elif dfc.DATA_SOURCE == 'sample': 
    summarize_data(1, verbose=True)

# %%
# %%time

# Generates video pairs from metadata file, defines a datapath per
# pair, and generates fakerframes and fakerprint for that pair.
def preprocess_data(istart=1, istop=None, batchsz=10):
#{
    if istop is None: istart, istop = 0, istart

    batchtimes, batchnum = [], 1
    for i in range(istart, istop):
    #{
        parttime = time.time()
        fpairs = df.faked_video_pairs(i)
        if not os.path.isdir(df.fakerdir(i)): os.mkdir(df.fakerdir(i))
        print(f"Preprocessing {len(fpairs)} video pairs in partition {df.trainpart(i)}:")
        for j, pc_pair in enumerate(fpairs):
        #{
            # This is some finagled code to pickup somewhere mid-partition
            #if re.split(r'[/.]', pc_pair[0])[-2] == 'wmoigsbnem': pickup = True
            #if not pickup: continue
        
            batchtimes.append(time.time())
            datapath = f"{df.fakerdir(i)}/{re.split(r'[/.]', pc_pair[0])[-2]}"
            if not os.path.isdir(datapath): os.mkdir(datapath)
            df.create_diff_frames(pc_pair[0], pc_pair[1], datapath)
            
            batchtimes[-1] = time.time() - batchtimes[-1]
            if len(batchtimes) == batchsz:
                print(f"  Average preprocess time per pair for batch {batchnum}: {np.average(batchtimes):.2f} sec")
                batchnum += 1; batchtimes = []
        #}
        print(f"  Total partition {df.trainpart(i)} preprocessing time: {(time.time()-parttime):.2f} sec")
    #}
#}

if dfc.DATA_SOURCE == 'sample':
    preprocess_data()

elif dfc.DATA_SOURCE == 'production': 
#{
    # With no arguments, preprocesses just the first partition (1334 videos). 
    # On my iMac, this averaged ~28 sec/video (or 10.5 hrs total).
    preprocess_data()
#}

# %%
# Just copies all the fakerprints into a single 
# for directory testing/debugging purposes

import shutil

dirlist = !ls -tr1 {df.fakerdir()}
for i, dfile in enumerate(dirlist): 
    shutil.copyfile(f"{df.fakerdir()}/{dfile}/fakerprint.jpg",
                    f"{df.fakerdir()}/../fakerprints/fakerprint{i}.jpg")
